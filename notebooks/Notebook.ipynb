# %% [markdown]
# # Park Hopper Routes
#
# ## 1. Introduction
#
# Welcome to the Park Hopper Routes data science notebook!
#
# This project explores and visualizes different travel routes between a selection of U.S. national parks while supporting software engineers developing an interactive website to display the information.
#
# Specifically, we compare two strategies:
#
# - **Greedy Nearest Neighbor (GNN)**: An algorithm that always visits the closest unvisited park next.
# - Random Route: A randomly ordered path between parks, used as a baseline for comparison.
#
# Using real-world latitude and longitude coordinates for the parks, we look up Google Maps travel distances and durations, then display both routes on an interactive Folium map. This allows for direct visual comparison between optimized and non-optimized routing strategies.
#
# Key features of this notebook:
#
# - Distance and time data fetched via API
# - Route plotting using Folium
# - Custom interactive map with legends and colored polylines
# - Designed for exploration of travel planning logic
# - Modular code (scripts) to assist software engineers in creating a website
#
# This tool could help prototype itinerary planning for national park road trips, and serves as a foundation for more advanced optimization and mapping features in the future.
#
# ## 2. Datasets and External Libraries
#
# ### 2.1. Datasets
#
# - Data was obtained from the National Park Service (https://www.nps.gov/index.htm) using their API (https://www.nps.gov/subjects/developer/api-documentation.htm).
# - United States Latitude and Longitude Data was obtained from Kaggle (https://www.kaggle.com/datasets/tennerimaheshwar/us-state-and-territory-latitude-and-longitude-data)
#
# ### 2.2. External Libraries

# %%
# JSON requests
import requests
import json

# Data manipulation
import numpy as np
import pandas as pd
import ast

# Displaying plots and maps
import matplotlib.pyplot as plt
import folium as fl # change if SWE need

# Dummy and greedy nearest neighbors algorithm requirements
import math
import googlemaps
import random

# Timing the algorithm
import time

# Neatly display dataframes
from tabulate import tabulate

# Display all fields with pandas
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 2.3. Inspect Raw Data JSON Response from NPS API
#
# We first inspected a JSON response to determine how to pull data from it. The API key has since been removed.

# %%
"""
# Inspect full JSON response of the first park to determine fields we need and data structure
api_key = "YOUR_KEY_HERE"
url = "https://developer.nps.gov/api/v1/parks"

params = {
    "limit": 1,
    "start": 0,
    "api_key": api_key
}

response = requests.get(url, params=params)
data = response.json()

# Print the full JSON response of the first park
print(json.dumps(data["data"][0], indent=2))
"""
# Out:
# {
#   "id": "77E0D7F0-1942-494A-ACE2-9004D2BDC59E",
#   "url": "https://www.nps.gov/abli/index.htm",
#   "fullName": "Abraham Lincoln Birthplace National Historical Park",
#   "parkCode": "abli",
#   "description": "For over a century people from around the world have come to rural Central Kentucky to honor the humble beginnings of our 16th president, Abraham Lincoln. His early life on Kentucky's frontier shaped his character and prepared him to lead the nation through Civil War. Visit our country's first memorial to Lincoln, built with donations from young and old, and the site of his childhood home.",
#   "latitude": "37.5858662",
#   "longitude": "-85.67330523",
#   "latLong": "lat:37.5858662, long:-85.67330523",
#   "activities": [
#     {
#       "id": "13A57703-BB1A-41A2-94B8-53B692EB7238",
#       "name": "Astronomy"
#     },
#     {
#       "id": "D37A0003-8317-4F04-8FB0-4CF0A272E195",
#       "name": "Stargazing"
#     },
#     {
#       "id": "1DFACD97-1B9C-4F5A-80F2-05593604799E",
#       "name": "Food"
#     },
#     {
#       "id": "C6D3230A-2CEA-4AFE-BFF3-DC1E2C2C4BB4",
#       "name": "Picnicking"
#     },
#     {
#       "id": "B33DC9B6-0B7D-4322-BAD7-A13A34C584A3",
#       "name": "Guided Tours"
#     },
#     {
#       "id": "A0631906-9672-4583-91DE-113B93DB6B6E",
#       "name": "Self-Guided Tours - Walking"
#     },
#     {
#       "id": "42FD78B9-2B90-4AA9-BC43-F10E9FEA8B5A",
#       "name": "Hands-On"
#     },
#     {
#       "id": "DF4A35E0-7983-4A3E-BC47-F37B872B0F25",
#       "name": "Junior Ranger Program"
#     },
#     {
#       "id": "0B685688-3405-4E2A-ABBA-E3069492EC50",
#       "name": "Wildlife Watching"
#     },
#     {
#       "id": "5A2C91D1-50EC-4B24-8BED-A2E11A1892DF",
#       "name": "Birdwatching"
#     },
#     {
#       "id": "0C0D142F-06B5-4BE1-8B44-491B90F93DEB",
#       "name": "Park Film"
#     },
#     {
#       "id": "C8F98B28-3C10-41AE-AA99-092B3B398C43",
#       "name": "Museum Exhibits"
#     },
#     {
#       "id": "24380E3F-AD9D-4E38-BF13-C8EEB21893E7",
#       "name": "Shopping"
#     },
#     {
#       "id": "467DC8B8-0B7D-436D-A026-80A22358F615",
#       "name": "Bookstore and Park Store"
#     },
#     {
#       "id": "43800AD1-D439-40F3-AAB3-9FB651FE45BB",
#       "name": "Gift Shop and Souvenirs"
#     }
#   ],
#   "topics": [
#     {
#       "id": "D10852A3-443C-4743-A5FA-6DD6D2A054B3",
#       "name": "Birthplace"
#     },
#     {
#       "id": "F669BC40-BDC4-41C0-9ACE-B2CD25373045",
#       "name": "Presidents"
#     },
#     {
#       "id": "0D00073E-18C3-46E5-8727-2F87B112DDC6",
#       "name": "Animals"
#     },
#     {
#       "id": "957EF2BD-AC6C-4B7B-BD9A-87593ADC6691",
#       "name": "Birds"
#     },
#     {
#       "id": "E25F3456-43ED-45DD-93BC-057F9B944F7A",
#       "name": "Caves, Caverns and Karst"
#     },
#     {
#       "id": "F0F97E32-2F29-41B4-AF98-9FBE8DAB36B1",
#       "name": "Geology"
#     },
#     {
#       "id": "4BE01DC5-52E6-4F18-8C9A-B22D65965F6D",
#       "name": "Groundwater"
#     },
#     {
#       "id": "0E1A04CC-EB51-4F18-93D4-EC0B0B4EC1E3",
#       "name": "Freshwater Springs"
#     },
#     {
#       "id": "A7359FC4-DAD8-45F5-AF15-7FF62F816ED3",
#       "name": "Night Sky"
#     }
#   ],
#   "states": "KY",
#   "contacts": {
#     "phoneNumbers": [
#       {
#         "phoneNumber": "2703583137",
#         "description": "",
#         "extension": "",
#         "type": "Voice"
#       },
#       {
#         "phoneNumber": "2703583874",
#         "description": "",
#         "extension": "",
#         "type": "Fax"
#       }
#     ],
#     "emailAddresses": [
#       {
#         "description": "",
#         "emailAddress": "ABLI_Administration@nps.gov"
#       }
#     ]
#   },
#   "entranceFees": [],
#   "entrancePasses": [],
#   "fees": [],
#   "directionsInfo": "The Birthplace Unit of the park is located approximately 2 miles south of the town of Hodgenville on U.S. Highway 31E South. The Boyhood Home Unit at Knob Creek is located approximately 10 miles northeast of the Birthplace Unit of the park.",
#   "directionsUrl": "http://www.nps.gov/abli/planyourvisit/directions.htm",
#   "operatingHours": [
#     {
#       "exceptions": [
#         {
#           "exceptionHours": {},
#           "startDate": "2025-11-27",
#           "name": "Park is Closed",
#           "endDate": "2025-11-27"
#         },
#         {
#           "exceptionHours": {},
#           "startDate": "2025-12-25",
#           "name": "Park is Closed",
#           "endDate": "2025-12-25"
#         },
#         {
#           "exceptionHours": {},
#           "startDate": "2026-01-01",
#           "name": "Park is Closed",
#           "endDate": "2026-01-01"
#         }
#       ],
#       "description": "Memorial Building:\nopen 9:00 am - 4:30 pm eastern time.\n\nBirthplace Unit Visitor Center and Grounds: \nopen 9:00 am - 5:00 pm eastern time.",
#       "standardHours": {
#         "wednesday": "9:00AM - 5:00PM",
#         "monday": "9:00AM - 5:00PM",
#         "thursday": "9:00AM - 5:00PM",
#         "sunday": "9:00AM - 5:00PM",
#         "tuesday": "9:00AM - 5:00PM",
#         "friday": "9:00AM - 5:00PM",
#         "saturday": "9:00AM - 5:00PM"
#       },
#       "name": "Birthplace Unit"
#     },
#     {
#       "exceptions": [],
#       "description": "The Boyhood Home Unit at Knob Creek Grounds:\nopen daily dawn to dusk.\n\nKnob Creek Tavern Visitor Center hours are different than the park unit.",
#       "standardHours": {
#         "wednesday": "Sunrise to Sunset",
#         "monday": "Sunrise to Sunset",
#         "thursday": "Sunrise to Sunset",
#         "sunday": "Sunrise to Sunset",
#         "tuesday": "Sunrise to Sunset",
#         "friday": "Sunrise to Sunset",
#         "saturday": "Sunrise to Sunset"
#       },
#       "name": "Boyhood Unit"
#     }
#   ],
#   "addresses": [
#     {
#       "postalCode": "42748",
#       "city": "Hodgenville",
#       "stateCode": "KY",
#       "countryCode": "US",
#       "provinceTerritoryCode": "",
#       "line1": "2995 Lincoln Farm Road",
#       "type": "Physical",
#       "line3": "",
#       "line2": ""
#     },
#     {
#       "postalCode": "42748",
#       "city": "Hodgenville",
#       "stateCode": "KY",
#       "countryCode": "US",
#       "provinceTerritoryCode": "",
#       "line1": "2995 Lincoln Farm Road",
#       "type": "Mailing",
#       "line3": "",
#       "line2": ""
#     }
#   ],
#   "images": [
#     {
#       "credit": "NPS Photo",
#       "title": "The Memorial Building with fall colors",
#       "altText": "The Memorial Building surrounded by fall colors",
#       "caption": "Over 200,000 people a year come to walk up the steps of the Memorial Building to visit the site where Abraham Lincoln was born",
#       "url": "https://www.nps.gov/common/uploads/structured_data/3C861078-1DD8-B71B-0B774A242EF6A706.jpg"
#     },
#     {
#       "credit": "NPS Photo",
#       "title": "The Memorial Building",
#       "altText": "The first memorial erected to honor Abraham Lincoln",
#       "caption": "The Memorial Building constructed on the traditional site of the birth of Abraham Lincoln.",
#       "url": "https://www.nps.gov/common/uploads/structured_data/3C861263-1DD8-B71B-0B71EF9B95F9644F.jpg"
#     },
#     {
#       "credit": "NPS Photo",
#       "title": "The Symbolic Birth Cabin of Abraham Lincoln",
#       "altText": "The symbolic birth cabin on the traditional site of the birth of Abraham Lincoln.",
#       "caption": "The symbolic birth cabin of Abraham Lincoln.",
#       "url": "https://www.nps.gov/common/uploads/structured_data/3C86137D-1DD8-B71B-0B978BACD7EBAEF1.jpg"
#     },
#     {
#       "credit": "NPS Photo",
#       "title": "Statue of the Lincoln Family in the Visitor Center",
#       "altText": "Statue of the Lincoln family in the park's Visitor Center",
#       "caption": "Visitors to the park can view the statue of the Lincoln family.",
#       "url": "https://www.nps.gov/common/uploads/structured_data/3C8614D1-1DD8-B71B-0B1AF72CA452B051.jpg"
#     }
#   ],
#   "weatherInfo": "There are four distinct seasons in Central Kentucky. However, temperature and weather conditions can vary widely within those seasons. Spring and Fall are generally pleasant with frequent rain showers. Summer is usually hot and humid. Winter is moderately cold with mixed precipitation.",
#   "name": "Abraham Lincoln Birthplace",
#   "designation": "National Historical Park",
#   "multimedia": [],
#   "relevanceScore": 1.0
# }

# %% [markdown]
# ### 2.4. Get Park Data with National Park Service API

# %%
# Get NPS park data
# Run from fetch_nps_data.py
# %run ../scripts/fetch_nps_data.py

# %% [markdown]
# ### 2.5. Import Generated Parks CSV and State Coordinates CSVs to Dataframe

# %%
parks = pd.read_csv('../data/raw/parks.csv')
states = pd.read_csv('../data/raw/states.csv')

# %% [markdown]
# ### 2.6. Inspect Data
#
# #### 2.6.1. Parks

# %%
# Print dataframe head
print('First five rows of dataframe')
display(parks.head())
print()
    
# Print dataframe sample
print('Random five rows of dataframe')
display(parks.sample(5))
print()
    
# Check for missing values (make sure amenities is included)
print('Check for Missing Values')
print(parks.isna().sum())
print()

# Check data types
print('Check Data Types')
print(parks.info())
print()

# Check values for each column
print('Describe Dataframe')
print(parks.describe(include = 'all'))
print()
    
# Check for duplicates
print('Count of Duplicated Rows')
print(parks.duplicated().sum())
print()

# Check for leading/trailing whitespace in strings
cols = ['name', 'designation', 'states', 'description', 'activities']   # string columns
for col in cols:
    if col in parks.columns:
        # Convert to string just in case, then check
        has_ws = parks[col].astype(str).apply(lambda x: x != x.strip())
        count = has_ws.sum()
        if count > 0:
            print(f"Column '{col}' has {count} rows with leading/trailing whitespace.")
        else: print(f"There is no leading/trailing whitespace in {col}.")  
print()

# Number of unique activities (important for web interface)
print(f"Unique Activities: {parks['activities'].nunique()}")

# Number of unique amenities (important for web interface)
print(f"Unique Amenities: {parks['amenities'].nunique()}")

print()
# Out:
# First five rows of dataframe
#                                      id  \
# 0  77E0D7F0-1942-494A-ACE2-9004D2BDC59E
# 1  6DA17C86-088E-4B4D-B862-7C1BD5CF236B
# 2  E4C7784E-66A0-4D44-87D0-3E072F5FEF43
# 3  1A47416F-DAA3-4137-9F30-14AF86B4E547
# 4  E6E1D22A-7A89-47F8-813C-B611059A8CF9
#
#                                                 name   latitude  longitude  \
# 0  Abraham Lincoln Birthplace National Historical...  37.585866 -85.673305
# 1                               Acadia National Park  44.409286 -68.247501
# 2                     Adams National Historical Park  42.255396 -71.011604
# 3                African American Civil War Memorial  38.916600 -77.026000
# 4            African Burial Ground National Monument  40.714527 -74.004474
#
#                 designation states  \
# 0  National Historical Park     KY
# 1             National Park     ME
# 2  National Historical Park     MA
# 3                       NaN     DC
# 4         National Monument     NY
#
#                                          description  \
# 0  For over a century people from around the worl...
# 1  Acadia National Park protects the natural beau...
# 2  From the sweet little farm at the foot of Penn...
# 3  Over 200,000 African-American soldiers and sai...
# 4  The African Burial Ground is the oldest and la...
#
#                                       directionsInfo  \
# 0  The Birthplace Unit of the park is located app...
# 1  From Boston take I-95 north to Augusta, Maine,...
# 2  Traveling on U.S. Interstate 93, take exit 7 -...
# 3  The memorial is located at the corner of Vermo...
# 4  The African Burial Ground National Monument is...
#
#                                        directionsUrl  \
# 0  http://www.nps.gov/abli/planyourvisit/directio...
# 1  http://www.nps.gov/acad/planyourvisit/directio...
# 2  http://www.nps.gov/adam/planyourvisit/directio...
# 3  http://www.nps.gov/afam/planyourvisit/directio...
# 4  http://www.nps.gov/afbg/planyourvisit/directio...
#
#                                          weatherInfo  \
# 0  There are four distinct seasons in Central Ken...
# 1  Located on Mount Desert Island in Maine, Acadi...
# 2  Be prepared for hot, humid weather. The histor...
# 3  Washington DC gets to see all four seasons. Hu...
# 4  http://forecast.weather.gov/MapClick.php?CityN...
#
#                                   url  \
# 0  https://www.nps.gov/abli/index.htm
# 1  https://www.nps.gov/acad/index.htm
# 2  https://www.nps.gov/adam/index.htm
# 3  https://www.nps.gov/afam/index.htm
# 4  https://www.nps.gov/afbg/index.htm
#
#                                           activities  \
# 0  Astronomy, Stargazing, Food, Picnicking, Guide...
# 1  Arts and Culture, Cultural Demonstrations, Ast...
# 2  Guided Tours, Self-Guided Tours - Walking, Liv...
# 3          Guided Tours, Self-Guided Tours - Walking
# 4  Arts and Culture, Guided Tours, Junior Ranger ...
#
#                                               topics  \
# 0  Birthplace, Presidents, Animals, Birds, Caves,...
# 1  Arts, Painting, Photography, Poetry and Litera...
# 2  American Revolution, Birthplace, Colonization ...
# 3  African American Heritage, Monuments and Memor...
# 4  African American Heritage, Archeology, Burial,...
#
#                                            image_url  \
# 0  https://www.nps.gov/common/uploads/structured_...
# 1  https://www.nps.gov/common/uploads/structured_...
# 2  https://www.nps.gov/common/uploads/structured_...
# 3  https://www.nps.gov/common/uploads/structured_...
# 4  https://www.nps.gov/common/uploads/structured_...
#
#                                        image_caption contact_phone  \
# 0  Over 200,000 people a year come to walk up the...    2703583137
# 1  As the tallest point on the eastern seaboard C...    2072883338
# 2  The Birthplaces of John and John Quincy Adams ...  617-770-1175
# 3            A poignant reminder of our nations past    2024266841
# 4                     African Burial Ground Memorial    2122384367
#
#                    contact_email  \
# 0    ABLI_Administration@nps.gov
# 1     acadia_information@nps.gov
# 2    ADAM_Visitor_Center@nps.gov
# 3          national_mall@nps.gov
# 4  african_burial_ground@nps.gov
#
#                                     physical_address  \
# 0      2995 Lincoln Farm Road, Hodgenville, KY 42748
# 1       25 Visitor Center Road, Bar Harbor, ME 04609
# 2                 1250 Hancock St., Quincy, MA 02169
# 3  1925 Vermont Avenue Northwest, Washington, DC ...
# 4  African Burial Ground National Monument, New Y...
#
#                                  mailing_address  \
# 0  2995 Lincoln Farm Road, Hodgenville, KY 42748
# 1               PO Box 177, Bar Harbor, ME 04609
# 2             135 Adams Street, Quincy, MA 02169
# 3       1100 Ohio Drive SW, Washington, DC 20242
# 4   African Burial Ground NM, New York, NY 10005
#
#                          operating_hours_description  \
# 0  Memorial Building:\r\nopen 9:00 am - 4:30 pm e...
# 1  Acadia National Park is open year-round. Check...
# 2  The Visitor Center is open 9:00 am to 5:00 pm ...
# 3  The African American Civil War Memorial is alw...
# 4                   INDOOR VISITOR CENTER AND MUSEUM
#
#                                       standard_hours  entrance_fee_cost  \
# 0  wednesday: 9:00AM - 5:00PM, monday: 9:00AM - 5...                NaN
# 1  wednesday: All Day, monday: All Day, thursday:...                6.0
# 2  wednesday: 9:00AM - 5:00PM, monday: Closed, th...               15.0
# 3  wednesday: All Day, monday: All Day, thursday:...                NaN
# 4  wednesday: 10:00AM - 4:00PM, monday: Closed, t...                NaN
#
#                    entrance_fee_title  \
# 0                                 NaN
# 1  Timed Entry Reservation - Location
# 2               Entrance - Per Person
# 3                                 NaN
# 4                                 NaN
#
#                             entrance_fee_description  entrance_pass_cost  \
# 0                                                NaN                 NaN
# 1  Vehicle reservations are not required for any ...                70.0
# 2  Entrance into the historic homes at Adams Nati...                45.0
# 3                                                NaN                 NaN
# 4                                                NaN                 NaN
#
#       entrance_pass_title                          entrance_pass_description  \
# 0                     NaN                                                NaN
# 1  Annual Entrance - Park  The Acadia Annual Pass is valid only at Acadia...
# 2  Annual Entrance - Park  Adams National Historical Park has a digital a...
# 3                     NaN                                                NaN
# 4                     NaN                                                NaN
#
#                                       amenities
# 0                              Accessible Rooms
# 1                              Accessible Rooms
# 2  Historical/Interpretive Information/Exhibits
# 3  Historical/Interpretive Information/Exhibits
# 4                                           NaN
# Random five rows of dataframe
#                                        id  \
# 107  7DC1050A-0DDE-4EF9-B777-3C9349BCC4DE
# 91   9192FFEE-4D88-4A03-A054-F47C33F0C3E9
# 376  0419867F-20D9-49CF-BC42-88F5A70AD32D
# 276  FA6450A4-D2F1-4B35-9817-EA01918597A6
# 338  BAB8E761-8BB9-4DFF-9D38-5D4BA9AB2BD4
#
#                                                  name   latitude   longitude  \
# 107                         Crater Lake National Park  42.940659 -122.133841
# 91   Chesapeake & Ohio Canal National Historical Park  39.000284  -77.248140
# 376                  Roger Williams National Memorial  41.829895  -71.410567
# 276                   Lowell National Historical Park  42.645537  -71.315887
# 338      Overmountain Victory National Historic Trail  35.140440  -81.377000
#
#                   designation       states  \
# 107             National Park           OR
# 91   National Historical Park     DC,MD,WV
# 376         National Memorial           RI
# 276  National Historical Park           MA
# 338   National Historic Trail  NC,SC,TN,VA
#
#                                            description  \
# 107  Crater Lake inspires awe. Native Americans wit...
# 91   Preserving America's early transportation hist...
# 376  "I acknowledge that to molest any person, Jew ...
# 276  Lowell’s water-powered textile mills catapulte...
# 338  Stretching 330-miles through four states (Virg...
#
#                                         directionsInfo  \
# 107  From the west (Medford) - Take Hwy 62 to the W...
# 91   The park has numerous access points. There is ...
# 376  From Interstate 95 North, take Exit 38 - State...
# 276  Paid parking is across the street from the Mus...
# 338  The trail travels over 330 miles through four ...
#
#                                          directionsUrl  \
# 107  http://www.nps.gov/crla/planyourvisit/directio...
# 91   http://www.nps.gov/choh/planyourvisit/directio...
# 376  http://www.nps.gov/rowi/planyourvisit/directio...
# 276  http://www.nps.gov/lowe/planyourvisit/directio...
# 338  http://www.nps.gov/ovvi/planyourvisit/directio...
#
#                                            weatherInfo  \
# 107  July, August, and September are your best bets...
# 91   The Washington, DC, area has a four-season Mid...
# 376  At Roger Williams National Memorial in Provide...
# 276  Summer: Throughout the summer, temperatures ra...
# 338  Temperatures for the area range from very hot ...
#
#                                     url  \
# 107  https://www.nps.gov/crla/index.htm
# 91   https://www.nps.gov/choh/index.htm
# 376  https://www.nps.gov/rowi/index.htm
# 276  https://www.nps.gov/lowe/index.htm
# 338  https://www.nps.gov/ovvi/index.htm
#
#                                             activities  \
# 107  Auto and ATV, Scenic Driving, Astronomy, Starg...
# 91   Biking, Road Biking, Boating, Boat Tour, Campi...
# 376  Arts and Culture, Cultural Demonstrations, Liv...
# 276  Arts and Culture, Craft Demonstrations, Cultur...
# 338  Auto and ATV, Scenic Driving, Biking, Mountain...
#
#                                                 topics  \
# 107  Architecture and Building, Arts, Painting, Pho...
# 91   Dams, Laborer and Worker, Schools and Educatio...
# 376  Arts, Poetry and Literature, Explorers and Exp...
# 276  Dams, Engineering, Industry, Factories, Mills,...
# 338  American Revolution, Military, Battlefields, T...
#
#                                              image_url  \
# 107  https://www.nps.gov/common/uploads/structured_...
# 91   https://www.nps.gov/common/uploads/structured_...
# 376  https://www.nps.gov/common/uploads/structured_...
# 276  https://www.nps.gov/common/uploads/structured_...
# 338  https://www.nps.gov/common/uploads/structured_...
#
#                                          image_caption contact_phone  \
# 107  Looking at Crater Lake and Wizard Island from ...    5415943000
# 91   The area of Great Falls is one of the reasons ...  301-739-4200
# 376                                  Roger Williams NM  401-521-7266
# 276  The Boott Cotton Mills is one of the best, mos...    9789705000
# 338  Hiking sections of the Overmountain Victory Tr...    8644612828
#
#                        contact_email  \
# 107               craterlake@nps.gov
# 91          CHOH_Information@nps.gov
# 376                rowi_info@nps.gov
# 276  LOWE_Public_Information@nps.gov
# 338         OVVI_Information@nps.gov
#
#                                      physical_address  \
# 107  Crater Lake National Park, Crater Lake, OR 97604
# 91         142 W. Potomac St., Williamsport, MD 21795
# 376       282 North Main Street, Providence, RI 02903
# 276                 115 John Street, Lowell, MA 01852
# 338               4001 Chesnee Hwy, Gaffney, SC 29341
#
#                                       mailing_address  \
# 107  Crater Lake National Park, Crater Lake, OR 97604
# 91         142 W. Potomac St., Williamsport, MD 21795
# 376       282 North Main Street, Providence, RI 02903
# 276                  67 Kirk Street, Lowell, MA 01852
# 338          338 New Pleasant Road, Gaffney, SC 29341
#
#                            operating_hours_description  \
# 107  Crater Lake National Park is open year-round, ...
# 91                The towpath is open 365 days a year.
# 376  We're excited to welcome you to the park! Our ...
# 276  June 15, 2025 – August 31, 2025\r\n\r\nThe Boo...
# 338  The Overmountain Victory National Historic Tra...
#
#                                         standard_hours  entrance_fee_cost  \
# 107  wednesday: All Day, monday: All Day, thursday:...               30.0
# 91   wednesday: Sunrise to Sunset, monday: Sunrise ...               20.0
# 376  wednesday: Sunrise to Sunset, monday: Sunrise ...                NaN
# 276  wednesday: 10:00AM - 5:00PM, monday: 10:00AM -...                NaN
# 338  wednesday: Sunrise to Sunset, monday: Sunrise ...                NaN
#
#              entrance_fee_title  \
# 107  Entrance - Private Vehicle
# 91   Entrance - Private Vehicle
# 376                         NaN
# 276                         NaN
# 338                         NaN
#
#                               entrance_fee_description  entrance_pass_cost  \
# 107  This is the summer entrance fee and is charged...                55.0
# 91   Pass is for one private, non-commercial vehicl...                35.0
# 376                                                NaN                 NaN
# 276                                                NaN                 NaN
# 338                                                NaN                 NaN
#
#         entrance_pass_title  \
# 107  Annual Entrance - Park
# 91   Annual Entrance - Park
# 376                     NaN
# 276                     NaN
# 338                     NaN
#
#                              entrance_pass_description           amenities
# 107  If you visit twice in 12 months purchasing the...    Accessible Rooms
# 91   Valid for one full year from the month of purc...    Accessible Rooms
# 376                                                NaN                 NaN
# 276                                                NaN    Accessible Rooms
# 338                                                NaN  Beach/Water Access
# Check for Missing Values
# id                               0
# name                             0
# latitude                         1
# longitude                        1
# designation                     35
# states                           0
# description                      0
# directionsInfo                   2
# directionsUrl                    0
# weatherInfo                      1
# url                              0
# activities                      10
# topics                           8
# image_url                        0
# image_caption                    0
# contact_phone                   16
# contact_email                    0
# physical_address                 0
# mailing_address                  0
# operating_hours_description      6
# standard_hours                   5
# entrance_fee_cost              360
# entrance_fee_title             360
# entrance_fee_description       360
# entrance_pass_cost             379
# entrance_pass_title            379
# entrance_pass_description      379
# amenities                       75
# dtype: int64
#
# Check Data Types
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 474 entries, 0 to 473
# Data columns (total 28 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           474 non-null    object
#  1   name                         474 non-null    object
#  2   latitude                     473 non-null    float64
#  3   longitude                    473 non-null    float64
#  4   designation                  439 non-null    object
#  5   states                       474 non-null    object
#  6   description                  474 non-null    object
#  7   directionsInfo               472 non-null    object
#  8   directionsUrl                474 non-null    object
#  9   weatherInfo                  473 non-null    object
#  10  url                          474 non-null    object
#  11  activities                   464 non-null    object
#  12  topics                       466 non-null    object
#  13  image_url                    474 non-null    object
#  14  image_caption                474 non-null    object
#  15  contact_phone                458 non-null    object
#  16  contact_email                474 non-null    object
#  17  physical_address             474 non-null    object
#  18  mailing_address              474 non-null    object
#  19  operating_hours_description  468 non-null    object
#  20  standard_hours               469 non-null    object
#  21  entrance_fee_cost            114 non-null    float64
#  22  entrance_fee_title           114 non-null    object
#  23  entrance_fee_description     114 non-null    object
#  24  entrance_pass_cost           95 non-null     float64
#  25  entrance_pass_title          95 non-null     object
#  26  entrance_pass_description    95 non-null     object
#  27  amenities                    399 non-null    object
# dtypes: float64(4), object(24)
# memory usage: 103.8+ KB
# None
#
# Describe Dataframe
#                                           id  \
# count                                    474
# unique                                   474
# top     77E0D7F0-1942-494A-ACE2-9004D2BDC59E
# freq                                       1
# mean                                     NaN
# std                                      NaN
# min                                      NaN
# 25%                                      NaN
# 50%                                      NaN
# 75%                                      NaN
# max                                      NaN
#
#                                                      name    latitude  \
# count                                                 474  473.000000
# unique                                                474         NaN
# top     Abraham Lincoln Birthplace National Historical...         NaN
# freq                                                    1         NaN
# mean                                                  NaN   38.569820
# std                                                   NaN    7.854124
# min                                                   NaN  -14.228659
# 25%                                                   NaN   35.388347
# 50%                                                   NaN   38.877313
# 75%                                                   NaN   41.661726
# max                                                   NaN   71.298324
#
#          longitude        designation states  \
# count   473.000000                439    474
# unique         NaN                 46    112
# top            NaN  National Monument     CA
# freq           NaN                 83     28
# mean    -94.110420                NaN    NaN
# std      27.069131                NaN    NaN
# min    -169.850378                NaN    NaN
# 25%    -109.451132                NaN    NaN
# 50%     -88.710010                NaN    NaN
# 75%     -77.035207                NaN    NaN
# max     145.723110                NaN    NaN
#
#                                               description  \
# count                                                 474
# unique                                                474
# top     For over a century people from around the worl...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                            directionsInfo  \
# count                                                 472
# unique                                                471
# top     By Car: Capital Beltway (I-495), Maryland oute...
# freq                                                    2
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                             directionsUrl  \
# count                                                 474
# unique                                                473
# top     http://www.nps.gov/bibe/planyourvisit/directio...
# freq                                                    2
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                               weatherInfo  \
# count                                                 473
# unique                                                436
# top     Washington DC gets to see all four seasons. Hu...
# freq                                                   12
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                        url  \
# count                                  474
# unique                                 474
# top     https://www.nps.gov/abli/index.htm
# freq                                     1
# mean                                   NaN
# std                                    NaN
# min                                    NaN
# 25%                                    NaN
# 50%                                    NaN
# 75%                                    NaN
# max                                    NaN
#
#                                                activities      topics  \
# count                                                 464         466
# unique                                                431         461
# top     Guided Tours, Self-Guided Tours - Walking, Jun...  Presidents
# freq                                                    7           3
# mean                                                  NaN         NaN
# std                                                   NaN         NaN
# min                                                   NaN         NaN
# 25%                                                   NaN         NaN
# 50%                                                   NaN         NaN
# 75%                                                   NaN         NaN
# max                                                   NaN         NaN
#
#                                                 image_url  \
# count                                                 474
# unique                                                474
# top     https://www.nps.gov/common/uploads/structured_...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                             image_caption contact_phone  \
# count                                                 474           458
# unique                                                474           408
# top     Over 200,000 people a year come to walk up the...    2024266841
# freq                                                    1             8
# mean                                                  NaN           NaN
# std                                                   NaN           NaN
# min                                                   NaN           NaN
# 25%                                                   NaN           NaN
# 50%                                                   NaN           NaN
# 75%                                                   NaN           NaN
# max                                                   NaN           NaN
#
#                 contact_email  \
# count                     474
# unique                    410
# top     national_mall@nps.gov
# freq                       13
# mean                      NaN
# std                       NaN
# min                       NaN
# 25%                       NaN
# 50%                       NaN
# 75%                       NaN
# max                       NaN
#
#                                          physical_address  \
# count                                                 474
# unique                                                458
# top     National Trails Office Regions 6, 7, & 8, Sant...
# freq                                                    7
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                  mailing_address  \
# count                                        474
# unique                                       422
# top     1100 Ohio Drive SW, Washington, DC 20242
# freq                                          15
# mean                                         NaN
# std                                          NaN
# min                                          NaN
# 25%                                          NaN
# 50%                                          NaN
# 75%                                          NaN
# max                                          NaN
#
#                               operating_hours_description  \
# count                                                 468
# unique                                                462
# top     The sites of National Mall and Memorial Parks ...
# freq                                                    4
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                            standard_hours  entrance_fee_cost  \
# count                                                 469         114.000000
# unique                                                110                NaN
# top     wednesday: All Day, monday: All Day, thursday:...                NaN
# freq                                                  172                NaN
# mean                                                  NaN          19.855263
# std                                                   NaN           9.532368
# min                                                   NaN           0.000000
# 25%                                                   NaN          10.000000
# 50%                                                   NaN          20.000000
# 75%                                                   NaN          25.000000
# max                                                   NaN          35.000000
#
#                 entrance_fee_title  \
# count                          114
# unique                           8
# top     Entrance - Private Vehicle
# freq                            65
# mean                           NaN
# std                            NaN
# min                            NaN
# 25%                            NaN
# 50%                            NaN
# 75%                            NaN
# max                            NaN
#
#                                  entrance_fee_description  entrance_pass_cost  \
# count                                                 114           95.000000
# unique                                                112                 NaN
# top     Adult (16 and older) -$15; good for 7 days ent...                 NaN
# freq                                                    2                 NaN
# mean                                                  NaN           47.842105
# std                                                   NaN           10.931426
# min                                                   NaN           35.000000
# 25%                                                   NaN           37.500000
# 50%                                                   NaN           45.000000
# 75%                                                   NaN           55.000000
# max                                                   NaN           70.000000
#
#            entrance_pass_title  \
# count                       95
# unique                       1
# top     Annual Entrance - Park
# freq                        95
# mean                       NaN
# std                        NaN
# min                        NaN
# 25%                        NaN
# 50%                        NaN
# 75%                        NaN
# max                        NaN
#
#                                 entrance_pass_description         amenities
# count                                                  95               399
# unique                                                 87                39
# top     Valid for one year through the month of purcha...  Accessible Rooms
# freq                                                    4               119
# mean                                                  NaN               NaN
# std                                                   NaN               NaN
# min                                                   NaN               NaN
# 25%                                                   NaN               NaN
# 50%                                                   NaN               NaN
# 75%                                                   NaN               NaN
# max                                                   NaN               NaN
#
# Count of Duplicated Rows
# 0
#
# There is no leading/trailing whitespace in name.
# There is no leading/trailing whitespace in designation.
# There is no leading/trailing whitespace in states.
# There is no leading/trailing whitespace in description.
# There is no leading/trailing whitespace in activities.
#
# Unique Activities: 431
# Unique Amenities: 39

# %% [markdown]
# #### 2.6.2. States

# %%
# Print dataframe head
print('First five rows of dataframe')
display(states.head())
print()
    
# Print dataframe sample
print('Random five rows of dataframe')
display(states.sample(5))
print()
    
# Check for missing values
print('Check for Missing Values')
print(states.isna().sum())
print()

# Check data types
print('Check Data Types')
print(states.info())
print()

# Check values for each column
print('Describe Dataframe')
print(states.describe(include = 'all'))
print()
    
# Check for duplicates
print('Count of Duplicated Rows')
print(states.duplicated().sum())
print()

# Check for leading/trailing whitespace in strings
cols = ['state&teritory', 'Name']  # string columns
for col in cols:
    if col in states.columns:
        # Convert to string just in case, then check
        has_ws = states[col].astype(str).apply(lambda x: x != x.strip())
        count = has_ws.sum()
        if count > 0:
            print(f"Column '{col}' has {count} rows with leading/trailing whitespace.")
        else: print(f"There is no leading/trailing whitespace in {col}.")
# Out:
# First five rows of dataframe
#   state&teritory   latitude   longitude        Name
# 0             AK  63.588753 -154.493062      Alaska
# 1             AL  32.318231  -86.902298     Alabama
# 2             AR  35.201050  -91.831833    Arkansas
# 3             AZ  34.048928 -111.093731     Arizona
# 4             CA  36.778261 -119.417932  California
# Random five rows of dataframe
#    state&teritory   latitude   longitude        Name
# 20             MD  39.045755  -76.641271    Maryland
# 12             IA  41.878003  -93.097702        Iowa
# 32             NM  34.972730 -105.032363  New Mexico
# 14             IL  40.633125  -89.398528    Illinois
# 46             VA  37.431573  -78.656894    Virginia
# Check for Missing Values
# state&teritory    0
# latitude          0
# longitude         0
# Name              0
# dtype: int64
#
# Check Data Types
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   state&teritory  61 non-null     object
#  1   latitude        61 non-null     float64
#  2   longitude       61 non-null     float64
#  3   Name            61 non-null     object
# dtypes: float64(2), object(2)
# memory usage: 2.0+ KB
# None
#
# Describe Dataframe
#        state&teritory   latitude   longitude    Name
# count              61  61.000000   61.000000      61
# unique             59        NaN         NaN      61
# top                DC        NaN         NaN  Alaska
# freq                2        NaN         NaN       1
# mean              NaN  34.065078  -71.870531     NaN
# std               NaN  17.899831   71.809011     NaN
# min               NaN -66.105720 -170.132217     NaN
# 25%               NaN  33.836081  -99.901813     NaN
# 50%               NaN  38.910832  -85.602364     NaN
# 75%               NaN  42.407211  -75.527670     NaN
# max               NaN  63.588753  171.989379     NaN
#
# Count of Duplicated Rows
# 0
#
# There is no leading/trailing whitespace in state&teritory.
# Column 'Name' has 9 rows with leading/trailing whitespace.

# %% [markdown]
# ### 2.7. Observations
#
# #### 2.7.1. Parks
#
# - There are a few missing values - if we want to include those values on our map, these should be removed. These are latitude, longitude, designation, directionsInfo, weatherInfo, activities, topics, contact_phone, operating_hours_description, standard_hours, entrance_fee_cost, and entrance_fee_title
# - Datatypes are all correct
# - There is no leading or trailing whitespace to strip
# - Activities between parks have a lot of overlap (431 unique vs. 474 parks!) and need to be streamlined/categorized
# - The instructions want a maximum of 9 geographical locations, so we will have to trim a subset of this data to use
# - We also have to remove National Parks not accessible by roads or extremely far away (AK, HI, PR, AS, and any other island parks)
#
# #### 2.7.2. States
#
# - The header `state&teritory` is a bit sloppy and also misspelled and will be changed to `abbreviation`, as well as making `Name` lowercase
# - Otherwise, everything appears fine
#
# ## 3. Data Processing and Visualization
#
# ### 3.1. Map of National Parks in the United States (Full NPS Dataset)
#
# In order to get an idea of the dataset and how to implement a route algorithm, it's best to view all of the coordinates of the parks on a map.

# %%
# Folium does not allow NaN coordinates, so we must remove those rows first
parks = parks.dropna(subset=['latitude', 'longitude'])

fig = fl.Figure(width=1200, height=800)
m = fl.Map(location=[39.8283, -98.5795], zoom_start=4)
fig.add_child(m)

for _, row in parks.iterrows():
    fl.Marker(
        location=[row['latitude'], row['longitude']],
        popup=row['name']
    ).add_to(m)

fig
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1d1ffbaec4e2e7bed614f9046a3ed544 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1d1ffbaec4e2e7bed614f9046a3ed544&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1d1ffbaec4e2e7bed614f9046a3ed544 = L.map(
#                 &quot;map_1d1ffbaec4e2e7bed614f9046a3ed544&quot;,
#                 {
#                     center: [39.8283, -98.5795],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8ce74ff35067601a516e792503197710 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8ce74ff35067601a516e792503197710.addTo(map_1d1ffbaec4e2e7bed614f9046a3ed544);
#
#
#             var marker_965c950dcf23b6c64defaa935e74a94f = L.marker(
#                 [37.5858662, -85.67330523],
#                 {
# }
#             ).addTo(map_1d1ffbaec4e2e7bed614f9046a3ed544);
#
#
#         var popup_4bf9428fbfdad2937b7a26b505d1fd50 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d5e068cc38ac3772e7b175a9ee850bb7 = $(`&lt;div id=&quot;html_d5e068cc38ac3772e7b175a9ee850bb7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Abraham Lincoln Birthplace National Historical Park&lt;/div&gt;`)[0];
#                 popup_4bf9428fbfdad2937b7a26b505d1fd50.setContent(html_d5e068cc38ac3772e7b175a9ee850bb7);
#
#
#
#         marker_965c950dcf23b6c64defaa935e74a94f.bindPopup(popup_4bf9428fbfdad2937b7a26b505d1fd50)
#         ;
#
#
#
#
#             var marker_3b3464ab712cb08a8a283162890c6adf = L.marker(
#                 [44.409286, -68.247501],
#                 {
# }
#             ).addTo(map_1d1ffbaec4e2e7bed614f9046a3ed544);
#
#
#         var popup_77277534558e6aca2b7866fc0c0c74cb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5848914904c7a8eb09010bc6fbb9bba6 = $(`&lt;div id=&quot;html_5848914904c7a8eb09010bc6fbb9bba6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Acadia National Park&lt;/div&gt;`)[0];
#                 popup_77277534558e6aca2b7866fc0c0c74cb.setContent(html_5848914904c7a8eb09010bc6fbb9bba6);
#
#
#
#         marker_3b3464ab712cb08a8a283162890c6adf.bindPopup(popup_77277534558e6aca2b7866fc0c0c74cb)
#         ;
#
#
#
#
#             var marker_d5340ee511d46beaa01753d750b65224 = L.marker(
#                 [42.2553961, -71.01160356],
#                 {
# }
#             ).addTo(map_1d1ffbaec4e2e7bed614f9046a3ed544);
#
#
#         var popup_fe745b847cdfce4b420bb96a9755a9f7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e61a4f0eeba73f66b0fecd3abb59caf2 = $(`&lt;div id=&quot;html_e61a4f0eeba73f66b0fecd3abb59caf2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Adams National Historical Park&lt;/div&gt;`)[0];
#                 popup_fe745b847cdfce4b420bb96a9755a9f7.setContent(html_e61a4f0eeba73f66b0fecd3abb59caf2);
#
#
#
#         marker_d5340ee511d46beaa01753d750b65224.bindPopup(popup_fe745b847cdfce4b420bb96a9755a9f7)
#         ;
#
#
#
#
#             var marker_f1456f130dea939ea3a1d3904150d497 = L.marker(
#                 [38.9166, -77.026],
#                 {
# }
#             ).addTo(map_1d1ffbaec4e2e7bed614f9046a3ed544);
#
#
#         var popup_7f598bed65577437721047de5e4ca529 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ef5795a4e29d162dee2b0aacaf7ab1a8 = $(`&lt;div id=&quot;html_ef5795a4e29d162dee2b0aacaf7ab1a8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;African American Civil War Memorial&lt;/div&gt;`)[0];
#                 popup_7f598bed65577437721047de5e4ca529.setContent(html_ef5795a4e29d162dee2b0aacaf7ab1a8);
#
#
#
#         marker_f1456f130dea939ea3a1d3904150d497.bindPopup(popup_7f598bed65577437721047de5e4ca529)
#         ;
#
#
#
#
#             var marker_851e93058bad4a5b33983bfaf6c5d37d = L.marker(
#                 [40.71452681, -74.00447358],
#                 {
# }
#             ).addTo(map_1d1ffbaec4e2e7bed614f9046a3ed544);
#
#
#         var popup_abe7b341bcd20afe63ba2da8c422dc1b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4ebbe956cd8cf945a9b3710087f57889 = $(`&lt;div id=&quot;html_4ebbe956cd8cf945a9b3710087f57889&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;African Burial Ground National Monument&lt;/div&gt;`)[0];
#                 popup_abe7b341bcd20afe63ba2da8c422dc1b.setContent(html_4ebbe956cd8cf945a9b3710087f57889);
#
#
#
#         marker_851e93058bad4a5b33983bfaf6c5d37d.bindPopup(popup_abe7b341bcd20afe63ba2da8c422d

# %% [markdown]
# There are several parks not accessible by car from the contiguous United States. These should be removed before creating a route algorithm that will be used for an interactive website. In addition, we noticed Dry Tortugas National Park is in Florida, but not accessible by car.
#
# ### 3.2. Clean Data
#
# #### 3.2.1. Parks
#
# - Remove parks too far for a roadtrip or not accessible by land (AK, HI, PR, AS, and any other island parks)
# - Remove any leading/trailing whitespace

# %%
# Drop parks in Alaska, Hawaii, Puerto Rico, American Samoa, St. Croix, Virgin Islands, etc., and not accessible by car (Dry Tortugas National Park)
exclude_states = ['AK', 'HI', 'PR', 'AS', 'SC', 'VI', 'FM', 'GU', 'MH', 'MP', 'PW']
parks = parks[~parks['states'].str.contains('|'.join(exclude_states))]

# Remove extra leading/trailing whitespace from park names
parks = parks[parks['name'].str.strip() != 'Dry Tortugas National Park']

# Save parks_master locally
parks_master = parks
parks_master.to_csv('../data/parks_master.csv', index=False)

# Create JSON of parks_master for use on the website
parks_master.to_json('../db.json/parks_master.json', orient='records', indent=2)

# %% [markdown]
# #### 3.2.1. States
#
# - Update column header labels
# - Create new column - tuple of latitude and longitude
# - Similar to above, delete states not in the contiguous US

# %%
# Rename column headings for consistency
states.rename(columns={'state&teritory': 'abbreviation', 'Name': 'name'}, inplace=True)

# Delete states not drivable to contiguous US
states_master = states[~states['abbreviation'].isin(exclude_states)]

# Save states_master locally
states_master.to_csv('../data/states_master.csv', index=False)

# Check new dataframe
print(states_master.head(5))
# Out:
#   abbreviation   latitude   longitude        name
# 1           AL  32.318231  -86.902298     Alabama
# 2           AR  35.201050  -91.831833    Arkansas
# 3           AZ  34.048928 -111.093731     Arizona
# 4           CA  36.778261 -119.417932  California
# 5           CO  39.550051 -105.782067    Colorado

# %% [markdown]
# ### 3.2. Map of National Parks in the Contiguous United States
#
# Like above, the best way to visualize this dataset is with a map. Here we check that all remaining parks are in the contiguous US and accessible by car.

# %%
fig = fl.Figure(width=1200, height=800)
m = fl.Map(location=[39.8283, -98.5795], zoom_start=4)
fig.add_child(m)

for _, row in parks_master.iterrows():
    fl.Marker(
        location=[row['latitude'], row['longitude']],
        popup=row['name']
    ).add_to(m)

fig
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f22ea85bf35f3871959ced165bdf9d2b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f22ea85bf35f3871959ced165bdf9d2b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f22ea85bf35f3871959ced165bdf9d2b = L.map(
#                 &quot;map_f22ea85bf35f3871959ced165bdf9d2b&quot;,
#                 {
#                     center: [39.8283, -98.5795],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3722e2a9ff6758630b99c8fa5e7b114c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3722e2a9ff6758630b99c8fa5e7b114c.addTo(map_f22ea85bf35f3871959ced165bdf9d2b);
#
#
#             var marker_1afa995a43169db518f761ff31417df4 = L.marker(
#                 [37.5858662, -85.67330523],
#                 {
# }
#             ).addTo(map_f22ea85bf35f3871959ced165bdf9d2b);
#
#
#         var popup_1c41004594efba927c6c40df35d89f11 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c1a5b1d2c35cf4150d4728919e6a538b = $(`&lt;div id=&quot;html_c1a5b1d2c35cf4150d4728919e6a538b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Abraham Lincoln Birthplace National Historical Park&lt;/div&gt;`)[0];
#                 popup_1c41004594efba927c6c40df35d89f11.setContent(html_c1a5b1d2c35cf4150d4728919e6a538b);
#
#
#
#         marker_1afa995a43169db518f761ff31417df4.bindPopup(popup_1c41004594efba927c6c40df35d89f11)
#         ;
#
#
#
#
#             var marker_c625edcdab3bb61fdb22421f15bd57a1 = L.marker(
#                 [44.409286, -68.247501],
#                 {
# }
#             ).addTo(map_f22ea85bf35f3871959ced165bdf9d2b);
#
#
#         var popup_ff221fb1f2677b00d49c88c88cafcbb2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_afa48e5d087482c781474abea0c610a6 = $(`&lt;div id=&quot;html_afa48e5d087482c781474abea0c610a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Acadia National Park&lt;/div&gt;`)[0];
#                 popup_ff221fb1f2677b00d49c88c88cafcbb2.setContent(html_afa48e5d087482c781474abea0c610a6);
#
#
#
#         marker_c625edcdab3bb61fdb22421f15bd57a1.bindPopup(popup_ff221fb1f2677b00d49c88c88cafcbb2)
#         ;
#
#
#
#
#             var marker_a6e8ad798bc7c0804fa791dfe0042c71 = L.marker(
#                 [42.2553961, -71.01160356],
#                 {
# }
#             ).addTo(map_f22ea85bf35f3871959ced165bdf9d2b);
#
#
#         var popup_2726388dc607451a4d62c3a83a9a6821 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7ddb95017e5adba7c52931cec9a4ee2c = $(`&lt;div id=&quot;html_7ddb95017e5adba7c52931cec9a4ee2c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Adams National Historical Park&lt;/div&gt;`)[0];
#                 popup_2726388dc607451a4d62c3a83a9a6821.setContent(html_7ddb95017e5adba7c52931cec9a4ee2c);
#
#
#
#         marker_a6e8ad798bc7c0804fa791dfe0042c71.bindPopup(popup_2726388dc607451a4d62c3a83a9a6821)
#         ;
#
#
#
#
#             var marker_13a8f935f6734264b74d1926387b4522 = L.marker(
#                 [38.9166, -77.026],
#                 {
# }
#             ).addTo(map_f22ea85bf35f3871959ced165bdf9d2b);
#
#
#         var popup_8abdf50f58863f3a0cba1ebbe320d773 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_368354368433d2a97cc72cb3808173b4 = $(`&lt;div id=&quot;html_368354368433d2a97cc72cb3808173b4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;African American Civil War Memorial&lt;/div&gt;`)[0];
#                 popup_8abdf50f58863f3a0cba1ebbe320d773.setContent(html_368354368433d2a97cc72cb3808173b4);
#
#
#
#         marker_13a8f935f6734264b74d1926387b4522.bindPopup(popup_8abdf50f58863f3a0cba1ebbe320d773)
#         ;
#
#
#
#
#             var marker_856e6770d5d3007c4486c4a8eed7dc4b = L.marker(
#                 [40.71452681, -74.00447358],
#                 {
# }
#             ).addTo(map_f22ea85bf35f3871959ced165bdf9d2b);
#
#
#         var popup_517853ccccc57d577e371aad77d6d173 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c8c2373e35764142d2e5827bd3b7f809 = $(`&lt;div id=&quot;html_c8c2373e35764142d2e5827bd3b7f809&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;African Burial Ground National Monument&lt;/div&gt;`)[0];
#                 popup_517853ccccc57d577e371aad77d6d173.setContent(html_c8c2373e35764142d2e5827bd3b7f809);
#
#
#
#         marker_856e6770d5d3007c4486c4a8eed7dc4b.bindPopup(popup_517853ccccc57d577e371aad77d6d

# %% [markdown]
# ### 3.3. Select Parks to Include for Routing Algorithm
#
# - Irrelevant fields will be dropped to simplify the data
# - The complete dataset started with 474 parks - for a route algorithm, this is way too many and we would end up with a cluttered route map.
# - We will select 9 parks roughly evenly distributed around the US to increase visual clarity.

# %%
# Drop irrelevant fields to simplify the data
relevant_fields = ['name', 'latitude', 'longitude', 'description', 'url', 'image_url']
parks_master = parks[relevant_fields]

# Trim down to a selected subset of 9 parks distributed throughout the US
listofparks_subset = ['Everglades National Park',
                    'Zion National Park',
                    'Big Bend National Park',
                    'Golden Gate National Recreation Area',
                    'Charles Young Buffalo Soldiers National Monument',
                    'Theodore Roosevelt National Park',
                    'Fort Union National Monument',
                    'Fire Island National Seashore',
                    'Mount Rushmore National Memorial'
                    ]

parks_subset = parks_master[parks_master['name'].isin(listofparks_subset)].reset_index(drop=True)
print(parks_subset)

# Save parks_subset locally
parks_subset.to_csv('../data/parks_subset.csv', index=False)

# Create JSON of parks_subset for use on the website
parks_subset.to_json('../db.json/parks_subset.json', orient='records', indent=2)
# Out:
#                                                name   latitude   longitude  \
# 0                            Big Bend National Park  29.298178 -103.229790
# 1  Charles Young Buffalo Soldiers National Monument  39.708178  -83.893286
# 2                          Everglades National Park  25.372942  -80.882003
# 3                     Fire Island National Seashore  40.696686  -73.000135
# 4                      Fort Union National Monument  35.907006 -105.014518
# 5              Golden Gate National Recreation Area  37.859825 -122.600739
# 6                  Mount Rushmore National Memorial  43.880370 -103.452519
# 7                  Theodore Roosevelt National Park  47.177773 -103.430008
# 8                                Zion National Park  37.298393 -113.026514
#
#                                          description  \
# 0  There is a place in Far West Texas where night...
# 1  Throughout his life, Charles Young overcame co...
# 2  Established in 1947 as the first national park...
# 3  Immerse yourself in an enchanting collage of c...
# 4  Exposed to the wind, within a sweeping valley ...
# 5  Experience a park so rich it supports 19 disti...
# 6  Majestic figures of George Washington, Thomas ...
# 7  When Theodore Roosevelt came to Dakota Territo...
# 8  Follow the paths where people have walked for ...
#
#                                   url  \
# 0  https://www.nps.gov/bibe/index.htm
# 1  https://www.nps.gov/chyo/index.htm
# 2  https://www.nps.gov/ever/index.htm
# 3  https://www.nps.gov/fiis/index.htm
# 4  https://www.nps.gov/foun/index.htm
# 5  https://www.nps.gov/goga/index.htm
# 6  https://www.nps.gov/moru/index.htm
# 7  https://www.nps.gov/thro/index.htm
# 8  https://www.nps.gov/zion/index.htm
#
#                                            image_url
# 0  https://www.nps.gov/common/uploads/structured_...
# 1  https://www.nps.gov/common/uploads/structured_...
# 2  https://www.nps.gov/common/uploads/structured_...
# 3  https://www.nps.gov/common/uploads/structured_...
# 4  https://www.nps.gov/common/uploads/structured_...
# 5  https://www.nps.gov/common/uploads/structured_...
# 6  https://www.nps.gov/common/uploads/structured_...
# 7  https://www.nps.gov/common/uploads/structured_...
# 8  https://www.nps.gov/common/uploads/structured_...

# %% [markdown]
# ## 4. Route Algorithm
#
# The first step is creating a baseline route model - random chance.
#
# ### 4.1. Baseline Model (Random Chance)

# %%
# Create model that randomly chooses next destination
# Create origin dictionary using our subset of 9 parks
keys_subset = parks_subset['name']

values_subset = [(parks_subset.loc[parks_subset['name'] == name, 'latitude'].values[0],  # clean this up to take the coordinate tuple directly
           parks_subset.loc[parks_subset['name'] == name, 'longitude'].values[0])
          for name in keys_subset]

origins_subset = dict(zip(keys_subset, values_subset))

def dummy_route(n, start=0):
    """
    Purpose:
    Given n parks and a starting location, creates a random route without visiting any location twice.

    Arguments:
    n = number of locations
    start = starting location by index (default: 0)
    """
    # Create a list of all indices (0 to n-1)
    indices = list(range(n))
    
    # Remove the starting point and randomly shuffle the rest
    indices.remove(start)
    random.shuffle(indices)
    
    # Add the starting point back to the beginning of the list
    route = [start] + indices
    
    return route

# Testing the function on 9 parks
# Timing the route calculation
start = time.time()

random_route_subset = dummy_route(9)

end = time.time()
elapsed = (end - start)

print(f'The randomly generated route is {random_route_subset} and took {elapsed:.0f} seconds to calculate.')
# Out:
# The randomly generated route is [0, 5, 3, 7, 2, 8, 1, 6, 4] and took 0 seconds to calculate.

# %% [markdown]
# ### 4.2. Create Google Maps Travel Data Arrays
#
# - Traditionally, route algorithms between geographical locations might use the Haversine distance, which is the linear distance between them accounting for the curvature of the Earth.
# - For this project, we have chosen to instead use Google Maps driving distances from their API.
# - For our 9 parks, we need to create an array of the driving distances (mi) and times (hrs) between each permutation (order matters) of 2 parks.
# - We decided to do this ahead of time to avoid calling the API each time (too slow for a dynamic map).
# - *Note: 3 parks had to have manually entered coordinates for nearby locations because they were not reachable by a Google Maps driving route.*
# - Subsequently, this functionality was moved in to generate_googlemaps_array.py where it was used to generate these arrays, and the API key was removed.

# %%
# Run from generate_googlemaps_array.py

# Initialize Google Maps API client
api_key_g = 'YOUR_API_KEY'
gmaps = googlemaps.Client(key=api_key_g)

fixed_coords = {
    "Everglades National Park": (25.4686, -80.4776),  # Homestead, FL
    "Fire Island National Seashore": (40.7551, -72.9878),  # Patchogue, NY
    "Zion National Park": (37.2594, -112.9507),  # Zion Canyon Visitor Center
}

values_subset = []
for name in keys_subset:
    if name in fixed_coords:
        coords = fixed_coords[name]
    else:
        lat = parks_subset.loc[parks_subset['name'] == name, 'latitude'].values[0]
        lon = parks_subset.loc[parks_subset['name'] == name, 'longitude'].values[0]
        coords = (lat, lon)
    values_subset.append(coords)

origins_subset = dict(zip(keys_subset, values_subset))


# Create origin dictionary using parks_subset
#keys_subset = parks_subset['name']

#values_subset = [(parks_subset.loc[parks_subset['name'] == name, 'latitude'].values[0],        # redundant/cleanup to get coordinates tuple directly
           #parks_subset.loc[parks_subset['name'] == name, 'longitude'].values[0])
          #for name in keys_subset]

# To compute trips from A to B
origins_subset = dict(zip(keys_subset, values_subset))

# To compute trips from B to A
destinations_subset = origins_subset

# Initialize distance matrix
travel_array_subset = np.zeros((len(origins_subset) * (len(destinations_subset) - 1), 4), dtype = object)

# Loop through all dictionary items
i = 0
for origin_name, origin_coords in origins_subset.items():
    for dest_name, dest_coords in destinations_subset.items():
        # Skip pairs where origin = destination (distance 0)
        if origin_name == dest_name:
            continue
        
        print(f"Origin: {origin_name} coords: {origin_coords}")
        print(f"Destination: {dest_name} coords: {dest_coords}")

        # Travel data from origin to destination
        result = gmaps.distance_matrix(origins=[origin_coords], destinations=[dest_coords], mode='driving')
        element = result['rows'][0]['elements'][0]
        # Check for valid result
        if element['status'] == 'OK':
            distance_meters = element['distance']['value']
            duration_seconds = element['duration']['value']
        else:
            print(f"Warning: No route found from {origin_name} to {dest_name}. Status: {element['status']}")
            distance_meters = np.inf  # Or a sentinel value indicating no valid route
            duration_seconds = np.inf
            
        travel_array_subset[i, 0] = origin_name
        travel_array_subset[i, 1] = dest_name
        travel_array_subset[i, 2] = np.round(distance_meters / 1609.344, 2)
        travel_array_subset[i, 3] = np.round(duration_seconds / 3600, 2)

        i += 1

        print(f"{origin_name} → {dest_name} = {np.round((distance_meters/1609.344),2)} mi ({np.round((duration_seconds/3600),2)} hrs)") # convert to miles and hours

        time.sleep(0.1)  # Pause to avoid API rate limits



# Print array
print("\nTravel Matrix:")
print(travel_array_subset)

# Save array
np.save('../data/arrays/travel_array_subset.npy', travel_array_subset)
# Out:
# Origin: Big Bend National Park coords: (29.29817767, -103.2297897)
# Destination: Charles Young Buffalo Soldiers National Monument coords: (39.70817829, -83.89328575)
# Big Bend National Park → Charles Young Buffalo Soldiers National Monument = 1518.85 mi (22.37 hrs)
# Origin: Big Bend National Park coords: (29.29817767, -103.2297897)
# Destination: Everglades National Park coords: (25.4686, -80.4776)
# Big Bend National Park → Everglades National Park = 1805.43 mi (26.47 hrs)
# Origin: Big Bend National Park coords: (29.29817767, -103.2297897)
# Destination: Fire Island National Seashore coords: (40.7551, -72.9878)
# Big Bend National Park → Fire Island National Seashore = 2173.17 mi (32.31 hrs)
# Origin: Big Bend National Park coords: (29.29817767, -103.2297897)
# Destination: Fort Union National Monument coords: (35.90700629, -105.0145185)
# Big Bend National Park → Fort Union National Monument = 547.37 mi (8.92 hrs)
# Origin: Big Bend National Park coords: (29.29817767, -103.2297897)
# Destination: Golden Gate National Recreation Area coords: (37.85982543, -122.6007386)
# Big Bend National Park → Golden Gate National Recreation Area = 1520.18 mi (22.72 hrs)
# Origin: Big Bend National Park coords: (29.29817767, -103.2297897)
# Destination: Mount Rushmore National Memorial coords: (43.88037021, -103.4525186)
# Big Bend National Park → Mount Rushmore National Memorial = 1159.98 mi (18.19 hrs)
# Origin: Big Bend National Park coords: (29.29817767, -103.2297897)
# Destination: Theodore Roosevelt National Park coords: (47.17777274, -103.4300083)
# Big Bend National Park → Theodore Roosevelt National Park = 1412.51 mi (22.18 hrs)
# Origin: Big Bend National Park coords: (29.29817767, -103.2297897)
# Destination: Zion National Park coords: (37.2594, -112.9507)
# Big Bend National Park → Zion National Park = 1072.09 mi (16.73 hrs)
# Origin: Charles Young Buffalo Soldiers National Monument coords: (39.70817829, -83.89328575)
# Destination: Big Bend National Park coords: (29.29817767, -103.2297897)
# Charles Young Buffalo Soldiers National Monument → Big Bend National Park = 1523.49 mi (22.54 hrs)
# Origin: Charles Young Buffalo Soldiers National Monument coords: (39.70817829, -83.89328575)
# Destination: Everglades National Park coords: (25.4686, -80.4776)
# Charles Young Buffalo Soldiers National Monument → Everglades National Park = 1197.93 mi (17.51 hrs)
# Origin: Charles Young Buffalo Soldiers National Monument coords: (39.70817829, -83.89328575)
# Destination: Fire Island National Seashore coords: (40.7551, -72.9878)
# Charles Young Buffalo Soldiers National Monument → Fire Island National Seashore = 671.43 mi (10.44 hrs)
# Origin: Charles Young Buffalo Soldiers National Monument coords: (39.70817829, -83.89328575)
# Destination: Fort Union National Monument coords: (35.90700629, -105.0145185)
# Charles Young Buffalo Soldiers National Monument → Fort Union National Monument = 1291.03 mi (19.71 hrs)
# Origin: Charles Young Buffalo Soldiers National Monument coords: (39.70817829, -83.89328575)
# Destination: Golden Gate National Recreation Area coords: (37.85982543, -122.6007386)
# Charles Young Buffalo Soldiers National Monument → Golden Gate National Recreation Area = 2415.18 mi (35.26 hrs)
# Origin: Charles Young Buffalo Soldiers National Monument coords: (39.70817829, -83.89328575)
# Destination: Mount Rushmore National Memorial coords: (43.88037021, -103.4525186)
# Charles Young Buffalo Soldiers National Monument → Mount Rushmore National Memorial = 1249.2 mi (18.09 hrs)
# Origin: Charles Young Buffalo Soldiers National Monument coords: (39.70817829, -83.89328575)
# Destination: Theodore Roosevelt National Park coords: (47.17777274, -103.4300083)
# Charles Young Buffalo Soldiers National Monument → Theodore Roosevelt National Park = 1293.77 mi (18.9 hrs)
# Origin: Charles Young Buffalo Soldiers National Monument coords: (39.70817829, -83.89328575)
# Destination: Zion National Park coords: (37.2594, -112.9507)
# Charles Young Buffalo Soldiers National Monument → Zion National Park = 1858.86 mi (27.19 hrs)
# Origin: Everglades National Park coords: (25.4686, -80.4776)
# Destination: Big Bend National Park coords: (29.29817767, -103.2297897)
# Everglades National Park → Big Bend National Park = 1808.81 mi (26.48 hrs)
# Origin: Everglades National Park coords: (25.4686, -80.4776)
# Destination: Charles Young Buffalo Soldiers National Monument coords: (39.70817829, -83.89328575)
# Everglades National Park → Charles Young Buffalo Soldiers National Monument = 1198.17 mi (17.57 hrs)
# Origin: Everglades National Park coords: (25.4686, -80.4776)
# Destination: Fire Island National Seashore coords: (40.7551, -72.9878)
# Everglades National Park → Fire Island National Seashore = 1370.51 mi (20.22 hrs)
# Origin: Everglades National Park coords: (25.4686, -80.4776)
# Destination: Fort Union National Monument coords: (35.90700629, -105.0145185)
# Everglades National Park → Fort Union National Monument = 1942.19 mi (28.66 hrs)
# Origin: Everglades National Park coords: (25.4686, -80.4776)
# Destination: Golden Gate National Recreation Area coords: (37.85982543, -122.6007386)
# Everglades National Park → Golden Gate National Recreation Area = 3094.39 mi (45.33 hrs)
# Origin: Everglades National Park coords: (25.4686, -80.4776)
# Destination: Mount Rushmore National Memorial coords: (43.88037021, -103.4525186)
# Everglades National Park → Mount Rushmore National Memorial = 2221.5 mi (32.02 hrs)
# Origin: Everglades National Park coords: (25.4686, -80.4776)
# Destination: Theodore Roosevelt National Park coords: (47.17777274, -103.4300083)
# Everglades National Park → Theodore Roosevelt National Park = 2394.01 mi (34.39 hrs)
# Origin: Everglades National Park coords: (25.4686, -80.4776)
# Destination: Zion National Park coords: (37.2594, -112.9507)
# Everglades National Park → Zion National Park = 2499.07 mi (37.27 hrs)
# Origin: Fire Island National Seashore coords: (40.7551, -72.9878)
# Destination: Big Bend National Park coords: (29.29817767, -103.2297897)
# Fire Island National Seashore → Big Bend National Park = 2176.09 mi (32.58 hrs)
# Origin: Fire Island National Seashore coords: (40.7551, -72.9878)
# Destination: Charles Young Buffalo Soldiers National Monument coords: (39.70817829, -83.89328575)
# Fire Island National Seashore → Charles Young Buffalo Soldiers National Monument = 661.03 mi (10.57 hrs)
# Origin: Fire Island National Seashore coords: (40.7551, -72.9878)
# Destination: Everglades National Park coords: (25.4686, -80.4776)
# Fire Island National Seashore → Everglades National Park = 1377.04 mi (20.4 hrs)
# Origin: Fire Island National Seashore coords: (40.7551, -72.9878)
# Destination: Fort Union National Monument coords: (35.90700629, -105.0145185)
# Fire Island National Seashore → Fort Union National Monument = 1933.37 mi (29.86 hrs)
# Origin: Fire Island National Seashore coords: (40.7551, -72.9878)
# Destination: Golden Gate National Recreation Area coords: (37.85982543, -122.6007386)
# Fire Island National Seashore → Golden Gate National Recreation Area = 2973.12 mi (44.06 hrs)
# Origin: Fire Island National Seashore coords: (40.7551, -72.9878)
# Destination: Mount Rushmore National Memorial coords: (43.88037021, -103.4525186)
# Fire Island National Seashore → Mount Rushmore National Memorial = 1783.23 mi (26.56 hrs)
# Origin: Fire Island National Seashore coords: (40.7551, -72.9878)
# Destination: Theodore Roosevelt National Park coords: (47.17777274, -103.4300083)
# Fire Island National Seashore → Theodore Roosevelt National Park = 1827.79 mi (27.37 hrs)
# Origin: Fire Island National Seashore coords: (40.7551, -72.9878)
# Destination: Zion National Park coords: (37.2594, -112.9507)
# Fire Island National Seashore → Zion National Park = 2475.92 mi (36.73 hrs)
# Origin: Fort Union National Monument coords: (35.90700629, -105.0145185)
# Destination: Big Bend National Park coords: (29.29817767, -103.2297897)
# Fort Union National Monument → Big Bend National Park = 552.62 mi (8.89 hrs)
# Origin: Fort Union National Monument coords: (35.90700629, -105.0145185)
# Destination: Charles Young Buffalo Soldiers National Monument coords: (39.70817829, -83.89328575)
# Fort Union National Monument → Charles Young Buffalo Soldiers National Monument = 1289.94 mi (19.6 hrs)
# Origin: Fort Union National Monument coords: (35.90700629, -105.0145185)
# Destination: Everglades National Park coords: (25.4686, -80.4776)
# Fort Union National Monument → Everglades National Park = 1940.21 mi (28.62 hrs)
# Origin: Fort Union National Monument coords: (35.90700629, -105.0145185)
# Destination: Fire Island National Seashore coords: (40.7551, -72.9878)
# Fort Union National Monument → Fire Island National Seashore = 1943.72 mi (29.63 hrs)
# Origin: Fort Union National Monument coords: (35.90700629, -105.0145185)
# Destination: Golden Gate National Recreation Area coords: (37.85982543, -122.6007386)
# Fort Union National Monument → Golden Gate National Recreation Area = 1252.73 mi (18.47 hrs)
# Origin: Fort Union National Monument coords: (35.90700629, -105.0145185)
# Destination: Mount Rushmore National Memorial coords: (43.88037021, -103.4525186)
# Fort Union National Monument → Mount Rushmore National Memorial = 679.7 mi (10.14 hrs)
# Origin: Fort Union National Monument coords: (35.90700629, -105.0145185)
# Destination: Theodore Roosevelt National Park coords: (47.17777274, -103.4300083)
# Fort Union National Monument → Theodore Roosevelt National Park = 919.16 mi (13.75 hrs)
# Origin: Fort Union National Monument coords: (35.90700629, -105.0145185)
# Destination: Zion National Park coords: (37.2594, -112.9507)
# Fort Union National Monument → Zion National Park = 639.2 mi (10.33 hrs)
# Origin: Golden Gate National Recreation Area coords: (37.85982543, -122.6007386)
# Destination: Big Bend National Park coords: (29.29817767, -103.2297897)
# Golden Gate National Recreation Area → Big Bend National Park = 1521.07 mi (22.73 hrs)
# Origin: Golden Gate National Recreation Area coords: (37.85982543, -122.6007386)
# Destination: Charles Young Buffalo Soldiers National Monument coords: (39.70817829, -83.89328575)
# Golden Gate National Recreation Area → Charles Young Buffalo Soldiers National Monument = 2397.01 mi (35.0 hrs)
# Origin: Golden Gate National Recreation Area coords: (37.85982543, -122.6007386)
# Destination: Everglades National Park coords: (25.4686, -80.4776)
# Golden Gate National Recreation Area → Everglades National Park = 3092.46 mi (45.26 hrs)
# Origin: Golden Gate National Recreation Area coords: (37.85982543, -122.6007386)
# Destination: Fire Island National Seashore coords: (40.7551, -72.9878)
# Golden Gate National Recreation Area → Fire Island National Seashore = 2978.14 mi (43.93 hrs)
# Origin: Golden Gate National Recreation Area coords: (37.85982543, -122.6007386)
# Destination: Fort Union National Monument coords: (35.90700629, -105.0145185)
# Golden Gate National Recreation Area → Fort Union National Monument = 1253.43 mi (18.49 hrs)
# Origin: Golden Gate National Recreation Area coords: (37.85982543, -122.6007386)
# Destination: Mount Rushmore National Memorial coords: (43.88037021, -103.4525186)
# Golden Gate National Recreation Area → Mount Rushmore National Memorial = 1370.88 mi (20.48 hrs)
# Origin: Golden Gate National Recreation Area coords: (37.85982543, -122.6007386)
# Destination: Theodore Roosevelt National Park coords: (47.17777274, -103.4300083)
# Golden Gate National Recreation Area → Theodore Roosevelt National Park = 1500.63 mi (22.51 hrs)
# Origin: Golden Gate National Recreation Area coords: (37.85982543, -122.6007386)
# Destination: Zion National Park coords: (37.2594, -112.9507)
# Golden Gate National Recreation Area → Zion National Park = 750.59 mi (11.68 hrs)
# Origin: Mount Rushmore National Memorial coords: (43.88037021, -103.4525186)
# Destination: Big Bend National Park coords: (29.29817767, -103.2297897)
# Mount Rushmore National Memorial → Big Bend National Park = 1160.85 mi (18.16 hrs)
# Origin: Mount Rushmore National Memorial coords: (43.88037021, -103.4525186)
# Destination: Charles Young Buffalo Soldiers National Monument coords: (39.70817829, -83.89328575)
# Mount Rushmore National Memorial → Charles Young Buffalo Soldiers National Monument = 1250.8 mi (18.04 hrs)
# Origin: Mount Rushmore National Memorial coords: (43.88037021, -103.4525186)
# Destination: Everglades National Park coords: (25.4686, -80.4776)
# Mount Rushmore National Memorial → Everglades National Park = 2219.52 mi (31.93 hrs)
# Origin: Mount Rushmore National Memorial coords: (43.88037021, -103.4525186)
# Destination: Fire Island National Seashore coords: (40.7551, -72.9878)
# Mount Rushmore National Memorial → Fire Island National Seashore = 1783.45 mi (26.45 hrs)
# Origin: Mount Rushmore National Memorial coords: (43.88037021, -103.4525186)
# Destination: Fort Union National Monument coords: (35.90700629, -105.0145185)
# Mount Rushmore National Memorial → Fort Union National Monument = 680.7 mi (10.33 hrs)
# Origin: Mount Rushmore National Memorial coords: (43.88037021, -103.4525186)
# Destination: Golden Gate National Recreation Area coords: (37.85982543, -122.6007386)
# Mount Rushmore National Memorial → Golden Gate National Recreation Area = 1367.26 mi (20.59 hrs)
# Origin: Mount Rushmore National Memorial coords: (43.88037021, -103.4525186)
# Destination: Theodore Roosevelt National Park coords: (47.17777274, -103.4300083)
# Mount Rushmore National Memorial → Theodore Roosevelt National Park = 273.72 mi (4.62 hrs)
# Origin: Mount Rushmore National Memorial coords: (43.88037021, -103.4525186)
# Destination: Zion National Park coords: (37.2594, -112.9507)
# Mount Rushmore National Memorial → Zion National Park = 932.93 mi (14.11 hrs)
# Origin: Theodore Roosevelt National Park coords: (47.17777274, -103.4300083)
# Destination: Big Bend National Park coords: (29.29817767, -103.2297897)
# Theodore Roosevelt National Park → Big Bend National Park = 1409.21 mi (22.11 hrs)
# Origin: Theodore Roosevelt National Park coords: (47.17777274, -103.4300083)
# Destination: Charles Young Buffalo Soldiers National Monument coords: (39.70817829, -83.89328575)
# Theodore Roosevelt National Park → Charles Young Buffalo Soldiers National Monument = 1296.28 mi (18.9 hrs)
# Origin: Theodore Roosevelt National Park coords: (47.17777274, -103.4300083)
# Destination: Everglades National Park coords: (25.4686, -80.4776)
# Theodore Roosevelt National Park → Everglades National Park = 2391.76 mi (34.32 hrs)
# Origin: Theodore Roosevelt National Park coords: (47.17777274, -103.4300083)
# Destination: Fire Island National Seashore coords: (40.7551, -72.9878)
# Theodore Roosevelt National Park → Fire Island National Seashore = 1828.94 mi (27.32 hrs)
# Origin: Theodore Roosevelt National Park coords: (47.17777274, -103.4300083)
# Destination: Fort Union National Monument coords: (35.90700629, -105.0145185)
# Theodore Roosevelt National Park → Fort Union National Monument = 920.24 mi (13.93 hrs)
# Origin: Theodore Roosevelt National Park coords: (47.17777274, -103.4300083)
# Destination: Golden Gate National Recreation Area coords: (37.85982543, -122.6007386)
# Theodore Roosevelt National Park → Golden Gate National Recreation Area = 1501.14 mi (22.61 hrs)
# Origin: Theodore Roosevelt National Park coords: (47.17777274, -103.4300083)
# Destination: Mount Rushmore National Memorial coords: (43.88037021, -103.4525186)
# Theodore Roosevelt National Park → Mount Rushmore National Memorial = 270.15 mi (4.58 hrs)
# Origin: Theodore Roosevelt National Park coords: (47.17777274, -103.4300083)
# Destination: Zion National Park coords: (37.2594, -112.9507)
# Theodore Roosevelt National Park → Zion National Park = 1142.47 mi (17.09 hrs)
# Origin: Zion National Park coords: (37.2594, -112.9507)
# Destination: Big Bend National Park coords: (29.29817767, -103.2297897)
# Zion National Park → Big Bend National Park = 1072.32 mi (16.77 hrs)
# Origin: Zion National Park coords: (37.2594, -112.9507)
# Destination: Charles Young Buffalo Soldiers National Monument coords: (39.70817829, -83.89328575)
# Zion National Park → Charles Young Buffalo Soldiers National Monument = 1856.34 mi (27.07 hrs)
# Origin: Zion National Park coords: (37.2594, -112.9507)
# Destination: Everglades National Park coords: (25.4686, -80.4776)
# Zion National Park → Everglades National Park = 2497.21 mi (37.22 hrs)
# Origin: Zion National Park coords: (37.2594, -112.9507)
# Destination: Fire Island National Seashore coords: (40.7551, -72.9878)
# Zion National Park → Fire Island National Seashore = 2476.59 mi (36.67 hrs)
# Origin: Zion National Park coords: (37.2594, -112.9507)
# Destination: Fort Union National Monument coords: (35.90700629, -105.0145185)
# Zion National Park → Fort Union National Monument = 639.53 mi (10.35 hrs)
# Origin: Zion National Park coords: (37.2594, -112.9507)
# Destination: Golden Gate National Recreation Area coords: (37.85982543, -122.6007386)
# Zion National Park → Golden Gate National Recreation Area = 756.31 mi (11.82 hrs)
# Origin: Zion National Park coords: (37.2594, -112.9507)
# Destination: Mount Rushmore National Memorial coords: (43.88037021, -103.4525186)
# Zion National Park → Mount Rushmore National Memorial = 931.63 mi (14.07 hrs)
# Origin: Zion National Park coords: (37.2594, -112.9507)
# Destination: Theodore Roosevelt National Park coords: (47.17777274, -103.4300083)
# Zion National Park → Theodore Roosevelt National Park = 1141.34 mi (17.07 hrs)
#
# Travel Matrix:
# [['Big Bend National Park'
#   'Charles Young Buffalo Soldiers National Monument' 1518.85 22.37]
#  ['Big Bend National Park' 'Everglades National Park' 1805.43 26.47]
#  ['Big Bend National Park' 'Fire Island National Seashore' 2173.17 32.31]
#  ['Big Bend National Park' 'Fort Union National Monument' 547.37 8.92]
#  ['Big Bend National Park' 'Golden Gate National Recreation Area' 1520.18
#   22.72]
#  ['Big Bend National Park' 'Mount Rushmore National Memorial' 1159.98
#   18.19]
#  ['Big Bend National Park' 'Theodore Roosevelt National Park' 1412.51
#   22.18]
#  ['Big Bend National Park' 'Zion National Park' 1072.09 16.73]
#  ['Charles Young Buffalo Soldiers National Monument'
#   'Big Bend National Park' 1523.49 22.54]
#  ['Charles Young Buffalo Soldiers National Monument'
#   'Everglades National Park' 1197.93 17.51]
#  ['Charles Young Buffalo Soldiers National Monument'
#   'Fire Island National Seashore' 671.43 10.44]
#  ['Charles Young Buffalo Soldiers National Monument'
#   'Fort Union National Monument' 1291.03 19.71]
#  ['Charles Young Buffalo Soldiers National Monument'
#   'Golden Gate National Recreation Area' 2415.18 35.26]
#  ['Charles Young Buffalo Soldiers National Monument'
#   'Mount Rushmore National Memorial' 1249.2 18.09]
#  ['Charles Young Buffalo Soldiers National Monument'
#   'Theodore Roosevelt National Park' 1293.77 18.9]
#  ['Charles Young Buffalo Soldiers National Monument' 'Zion National Park'
#   1858.86 27.19]
#  ['Everglades National Park' 'Big Bend National Park' 1808.81 26.48]
#  ['Everglades National Park'
#   'Charles Young Buffalo Soldiers National Monument' 1198.17 17.57]
#  ['Everglades National Park' 'Fire Island National Seashore' 1370.51
#   20.22]
#  ['Everglades National Park' 'Fort Union National Monument' 1942.19 28.66]
#  ['Everglades National Park' 'Golden Gate National Recreation Area'
#   3094.39 45.33]
#  ['Everglades National Park' 'Mount Rushmore National Memorial' 2221.5
#   32.02]
#  ['Everglades National Park' 'Theodore Roosevelt National Park' 2394.01
#   34.39]
#  ['Everglades National Park' 'Zion National Park' 2499.07 37.27]
#  ['Fire Island National Seashore' 'Big Bend National Park' 2176.09 32.58]
#  ['Fire Island National Seashore'
#   'Charles Young Buffalo Soldiers National Monument' 661.03 10.57]
#  ['Fire Island National Seashore' 'Everglades National Park' 1377.04 20.4]
#  ['Fire Island National Seashore' 'Fort Union National Monument' 1933.37
#   29.86]
#  ['Fire Island National Seashore' 'Golden Gate National Recreation Area'
#   2973.12 44.06]
#  ['Fire Island National Seashore' 'Mount Rushmore National Memorial'
#   1783.23 26.56]
#  ['Fire Island National Seashore' 'Theodore Roosevelt National Park'
#   1827.79 27.37]
#  ['Fire Island National Seashore' 'Zion National Park' 2475.92 36.73]
#  ['Fort Union National Monument' 'Big Bend National Park' 552.62 8.89]
#  ['Fort Union National Monument'
#   'Charles Young Buffalo Soldiers National Monument' 1289.94 19.6]
#  ['Fort Union National Monument' 'Everglades National Park' 1940.21 28.62]
#  ['Fort Union National Monument' 'Fire Island National Seashore' 1943.72
#   29.63]
#  ['Fort Union National Monument' 'Golden Gate National Recreation Area'
#   1252.73 18.47]
#  ['Fort Union National Monument' 'Mount Rushmore National Memorial' 679.7
#   10.14]
#  ['Fort Union National Monument' 'Theodore Roosevelt National Park'
#   919.16 13.75]
#  ['Fort Union National Monument' 'Zion National Park' 639.2 10.33]
#  ['Golden Gate National Recreation Area' 'Big Bend National Park' 1521.07
#   22.73]
#  ['Golden Gate National Recreation Area'
#   'Charles Young Buffalo Soldiers National Monument' 2397.01 35.0]
#  ['Golden Gate National Recreation Area' 'Everglades National Park'
#   3092.46 45.26]
#  ['Golden Gate National Recreation Area' 'Fire Island National Seashore'
#   2978.14 43.93]
#  ['Golden Gate National Recreation Area' 'Fort Union National Monument'
#   1253.43 18.49]
#  ['Golden Gate National Recreation Area'
#   'Mount Rushmore National Memorial' 1370.88 20.48]
#  ['Golden Gate National Recreation Area'
#   'Theodore Roosevelt National Park' 1500.63 22.51]
#  ['Golden Gate National Recreation Area' 'Zion National Park' 750.59
#   11.68]
#  ['Mount Rushmore National Memorial' 'Big Bend National Park' 1160.85
#   18.16]
#  ['Mount Rushmore National Memorial'
#   'Charles Young Buffalo Soldiers National Monument' 1250.8 18.04]
#  ['Mount Rushmore National Memorial' 'Everglades National Park' 2219.52
#   31.93]
#  ['Mount Rushmore National Memorial' 'Fire Island National Seashore'
#   1783.45 26.45]
#  ['Mount Rushmore National Memorial' 'Fort Union National Monument' 680.7
#   10.33]
#  ['Mount Rushmore National Memorial'
#   'Golden Gate National Recreation Area' 1367.26 20.59]
#  ['Mount Rushmore National Memorial' 'Theodore Roosevelt National Park'
#   273.72 4.62]
#  ['Mount Rushmore National Memorial' 'Zion National Park' 932.93 14.11]
#  ['Theodore Roosevelt National Park' 'Big Bend National Park' 1409.21
#   22.11]
#  ['Theodore Roosevelt National Park'
#   'Charles Young Buffalo Soldiers National Monument' 1296.28 18.9]
#  ['Theodore Roosevelt National Park' 'Everglades National Park' 2391.76
#   34.32]
#  ['Theodore Roosevelt National Park' 'Fire Island National Seashore'
#   1828.94 27.32]
#  ['Theodore Roosevelt National Park' 'Fort Union National Monument'
#   920.24 13.93]
#  ['Theodore Roosevelt National Park'
#   'Golden Gate National Recreation Area' 1501.14 22.61]
#  ['Theodore Roosevelt National Park' 'Mount Rushmore National Memorial'
#   270.15 4.58]
#  ['Theodore Roosevelt National Park' 'Zion National Park' 1142.47 17.09]
#  ['Zion National Park' 'Big Bend National Park' 1072.32 16.77]
#  ['Zion National Park' 'Charles Young Buffalo Soldiers National Monument'
#   1856.34 27.07]
#  ['Zion National Park' 'Everglades National Park' 2497.21 37.22]
#  ['Zion National Park' 'Fire Island National Seashore' 2476.59 36.67]
#  ['Zion National Park' 'Fort Union National Monument' 639.53 10.35]
#  ['Zion National Park' 'Golden Gate National Recreation Area' 756.31
#   11.82]
#  ['Zion National Park' 'Mount Rushmore National Memorial' 931.63 14.07]
#  ['Zion National Park' 'Theodore Roosevelt National Park' 1141.34 17.07]]

# %% [markdown]
# Now that the travel array is created, the trip starting point needs to be defined.
#
# ### 4.3. Define Vacation Starting Point
#
# - Instead of one of the 9 parks, the center point of the user's home state is the starting point.
# - We need the coordinates of the starting point, so a simple lookup was performed from the states dataset.
# - The full functionality of this step was later added to map.py

# %%
# Full functionality added to map.py
# Specify traveler's home state and lookup coordinates (example: NY)
home_state = 'NY'    # This field will be specified on website
home_state_coords = states_master.loc[states_master['abbreviation'] == home_state, ['latitude', 'longitude']].values[0].tolist()
print(f'The user\'s home state is {home_state} and their starting coordinates for travel are {home_state_coords}.')
# Out:
# The user's home state is NY and their starting coordinates for travel are [43.299428, -74.217933].

# %% [markdown]
# ### 4.4. Greedy Nearest Neighbors Algorithm
#
# A fast, intuitive method for route optimization that builds a path by always visiting the closest unvisited location next.
#
# #### 4.4.1. Prepare Dataframe and Matrix for GNN
#
# - GNN requires an array of the distances between every permutation of parks
#     - This is constructed from data in our previously created travel array

# %%
# Create new dataframe with just park names and coordinates
parks_gnn_subset = parks_subset[['name', 'latitude', 'longitude']].reset_index(drop=True)

# Set up empty array for GNN 
park_list = list(parks_subset['name'])  # This ensures same order
park_indices = {name: idx for idx, name in enumerate(park_list)}
n = len(park_list)
gnn_matrix = np.full((n, n), np.inf)  # fill with infinite distances to start

# Populate matrix from pre-calculated travel array travel_array_subset.npy (containing Google Maps data)
travel_array_subset = np.load('../data/arrays/travel_array_subset.npy', allow_pickle=True)
for row in travel_array_subset:
    origin, destination, dist_mi, _ = row
    i = park_indices[origin]
    j = park_indices[destination]
    gnn_matrix[i][j] = dist_mi

print(gnn_matrix)
# Out:
# [[    inf 1518.85 1805.43 2173.17  547.37 1520.18 1159.98 1412.51 1072.09]
#  [1523.49     inf 1197.93  671.43 1291.03 2415.18 1249.2  1293.77 1858.86]
#  [1808.81 1198.17     inf 1370.51 1942.19 3094.39 2221.5  2394.01 2499.07]
#  [2176.09  661.03 1377.04     inf 1933.37 2973.12 1783.23 1827.79 2475.92]
#  [ 552.62 1289.94 1940.21 1943.72     inf 1252.73  679.7   919.16  639.2 ]
#  [1521.07 2397.01 3092.46 2978.14 1253.43     inf 1370.88 1500.63  750.59]
#  [1160.85 1250.8  2219.52 1783.45  680.7  1367.26     inf  273.72  932.93]
#  [1409.21 1296.28 2391.76 1828.94  920.24 1501.14  270.15     inf 1142.47]
#  [1072.32 1856.34 2497.21 2476.59  639.53  756.31  931.63 1141.34     inf]]

# %% [markdown]
# This array is essentially a distance lookup chart of every permutation of 2 parks. Now it can be implemented in the GNN algorithm.
# - *Note: Because driving distance, and not absolute or Haversine distance, is used, the order of the 2 locations matters*
#
# #### 4.4.2. GNN Algorithm Function

# %%
# Greedy Nearest Neighbor function
def greedy_nearest_neighbor(gnn_matrix, start=0):
    """
    Purpose:
    Determine the optimal route through a set of locations given the distances between them while not returning to the same one twice.

    Arguments:
    gnn_matrix: array or matrix containing distances between all permutations of location pairs
    start: starting location by index (default: 0)
    """
    n = gnn_matrix.shape[0]
    visited = [False] * n
    route = [start] # 0 or state-specific coordinate
    visited[start] = True

    current = start
    for _ in range(n-1):
        # Find nearest unvisited park
        distances = gnn_matrix[current]
        nearest = None
        nearest_dist = float('inf')
        for i in range(n):
            if not visited[i] and distances[i] < nearest_dist:
                nearest = i
                nearest_dist = distances[i]

        route.append(nearest)
        visited[nearest] = True
        current = nearest

    return route

# Example usage:
# Assume travel matrix is your NxN numpy array

# Time the route calculation
start = time.time()

route_subset = greedy_nearest_neighbor(gnn_matrix, start=0)

end = time.time()
elapsed = end - start

print(f'The algorithm generated route is {route_subset} and took {elapsed:.0f} seconds to calculate.')
# Out:
# The algorithm generated route is [0, 4, 8, 5, 6, 7, 1, 3, 2] and took 0 seconds to calculate.

# %% [markdown]
# ## 5. Comparison of Random and GNN Routes
#
# Now that we have a random and GNN route, let's compare them.
#
# ### 5.1. Map Visualization

# %%
def plot_route_on_map(route_indices, park_coords, park_names):
    """
    Purpose:
    Plot a route on a Folium map with markers and lines between them.

    Arguments:
    route_indices: list of indices in visiting order
    park_coords: list of (lat, lon) tuples in the order of park_names
    park_names: list of park names
    line_color: color of line connecting locations
    """

def plot_route_on_map(route_indices, park_coords, park_names, line_color='blue'):
    """
    Purpose:
    Plot a route on a Folium map with markers and lines between them.

    Arguments:
    route_indices: list of indices in visiting order
    park_coords: list of (lat, lon) tuples in the order of park_names
    park_names: list of park names
    line_color: color of line connecting locations
    """
    route_points = []
    for idx in route_indices:
        lat, lon = park_coords[idx]
        fl.Marker(
            location=[lat, lon],
            popup=park_names[idx],
            tooltip=park_names[idx]
        ).add_to(m)
        route_points.append((lat, lon))

    fl.PolyLine(route_points, color=line_color, weight=3, opacity=0.7).add_to(m)

# Create the map centered on the center of the US
m = fl.Map(location=[39.8283, -98.5795], zoom_start=4)

# Plot GNN route in blue
plot_route_on_map(route_subset, park_coords, park_names, line_color='blue')

# Plot random route in red
plot_route_on_map(random_route_subset, park_coords, park_names, line_color='red')

# Display the combined map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_98da4fdba7664665499b89301b766c85 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_98da4fdba7664665499b89301b766c85&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_98da4fdba7664665499b89301b766c85 = L.map(
#                 &quot;map_98da4fdba7664665499b89301b766c85&quot;,
#                 {
#                     center: [39.8283, -98.5795],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0a9fb9c06912ea66d04946ffc2c463f2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0a9fb9c06912ea66d04946ffc2c463f2.addTo(map_98da4fdba7664665499b89301b766c85);
#
#
#             var marker_b4b56caafa65aca4b8f70dff27249f90 = L.marker(
#                 [29.29817767, -103.2297897],
#                 {
# }
#             ).addTo(map_98da4fdba7664665499b89301b766c85);
#
#
#         var popup_41a61abc97cc2d4b1be4e573a67c2903 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_faa4cec1320405b20aa201a547fe290f = $(`&lt;div id=&quot;html_faa4cec1320405b20aa201a547fe290f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Big Bend National Park&lt;/div&gt;`)[0];
#                 popup_41a61abc97cc2d4b1be4e573a67c2903.setContent(html_faa4cec1320405b20aa201a547fe290f);
#
#
#
#         marker_b4b56caafa65aca4b8f70dff27249f90.bindPopup(popup_41a61abc97cc2d4b1be4e573a67c2903)
#         ;
#
#
#
#
#             marker_b4b56caafa65aca4b8f70dff27249f90.bindTooltip(
#                 `&lt;div&gt;
#                      Big Bend National Park
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_9b302c7f3d1a60c423437b900ef6746d = L.marker(
#                 [35.90700629, -105.0145185],
#                 {
# }
#             ).addTo(map_98da4fdba7664665499b89301b766c85);
#
#
#         var popup_d48dddadf955d3f40bfc1ab51da01922 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_035689b012b973f8111349b4c00570c0 = $(`&lt;div id=&quot;html_035689b012b973f8111349b4c00570c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Fort Union National Monument&lt;/div&gt;`)[0];
#                 popup_d48dddadf955d3f40bfc1ab51da01922.setContent(html_035689b012b973f8111349b4c00570c0);
#
#
#
#         marker_9b302c7f3d1a60c423437b900ef6746d.bindPopup(popup_d48dddadf955d3f40bfc1ab51da01922)
#         ;
#
#
#
#
#             marker_9b302c7f3d1a60c423437b900ef6746d.bindTooltip(
#                 `&lt;div&gt;
#                      Fort Union National Monument
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_1fe3d95423a21324ff0daf35bd8566f5 = L.marker(
#                 [37.2594, -112.9507],
#                 {
# }
#             ).addTo(map_98da4fdba7664665499b89301b766c85);
#
#
#         var popup_1d985fae7e6d3167c9081bc1102e2580 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9c25fc45fd2255d13930f2cfe8b0bd1e = $(`&lt;div id=&quot;html_9c25fc45fd2255d13930f2cfe8b0bd1e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Zion National Park&lt;/div&gt;`)[0];
#                 popup_1d985fae7e6d3167c9081bc1102e2580.setContent(html_9c25fc45fd2255d13930f2cfe8b0bd1e);
#
#
#
#         marker_1fe3d95423a21324ff0daf35bd8566f5.bindPopup(popup_1d985fae7e6d3167c9081bc1102e2580)
#         ;
#
#
#
#
#             marker_1fe3d95423a21324ff0daf35bd8566f5.bindTooltip(
#                 `&lt;div&gt;
#                      Zion National Park
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_5b6454b75a18a002fea1473ea4c5af39 = L.marker(
#                 [37.85982543, -122.6007386],
#                 {
# }
#             ).addTo(map_98da4fdba7664665499b89301b766c85);
#
#
#         var popup_32eef5b63d44608f2b0d1cfb222f02e1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_67b23cca3e7e53470ae61d5011cd9de5 = $(`&lt;div id=&quot;html_67b23cca3e7e53470ae61d5011cd9de5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Golden Gate National Recreation Area&lt;/div&gt;`)[0];
#                 popup_32eef5b63d44608f2b0d1cfb222f02e1.setContent(html_67b23cca3e7e53470ae61d5011cd9de5);
#
#
#
#         ma

# %% [markdown]
# From this map, it's clear that the GNN route (blue) is much shorter and more efficient than the random route (red)
#
# ### 5.2. Trip Information Tables
#
# Now let's look at the data for each leg of the two routes.

# %%
# Creating a more logical display table of stops, travel distance and time per stop, and total travel distance and time
# This can be displayed in a window near the map on the dashboard

# Convert travel matrix into df
travel_df = pd.DataFrame(travel_array_subset, columns=['Origin', 'Destination', 'Distance (mi)', 'Duration (hrs)'])

# Combine into a function
def build_route_table_with_totals(route, park_list, travel_df):
    """
    Purpose:
    Build a dataframe with Origin, Destination, Distance (mi), and Duration (hrs), and numerical totals, for each leg of the route.

    Arguments:
    route: list of indices of the order of visiting each location
    park_list: list of park names
    travel_df: dataframe containing Origin, Destination, Distance (mi), and Duration (hrs)
    """
    route_info = []
    total_distance = 0
    total_duration = 0

    for i in range(len(route) - 1):
        origin = park_list[route[i]]
        destination = park_list[route[i + 1]]

        # Look up distance and duration
        row = travel_df[(travel_df['Origin'] == origin) & (travel_df['Destination'] == destination)]

        if not row.empty:
            distance = row['Distance (mi)'].values[0]
            duration = row['Duration (hrs)'].values[0]
            total_distance += distance
            total_duration += duration
        else:
            distance = None
            duration = None

        route_info.append({
            'From': origin,
            'To': destination,
            'Distance (mi)': distance,
            'Duration (hrs)': duration
        })

    # Append total row
    route_info.append({
        'From': 'Totals',
        'To': '',
        'Distance (mi)': round(total_distance, 2),
        'Duration (hrs)': round(total_duration, 2)
    })

    return pd.DataFrame(route_info)

# Display in an easy to read format
def display_route_table(table, title="Route Summary"):
    print(f"\n\033[1m{title}\033[0m")  # Bold title
    print(tabulate(
        table,
        headers="keys" if isinstance(table, pd.DataFrame) else "firstrow",
        tablefmt="fancy_grid",
        floatfmt=".2f"
    ))

# Build the route table using dummy route and conver to df for analysis
route_table_random = build_route_table_with_totals(random_route_subset, park_list, travel_df)
route_table_random = pd.DataFrame(route_table_random)

# Build the route table using algorithm route and convert to df for analysis
route_table_gnn = build_route_table_with_totals(route_subset, park_list, travel_df)
route_table_gnn = pd.DataFrame(route_table_gnn)

# Display tables
display_route_table(route_table_random)
display_route_table(route_table_gnn)
# Out:
# Route Summary
# ╒════╤══════════════════════════════════════════════════╤══════════════════════════════════════════════════╤═════════════════╤══════════════════╕
# │    │ From                                             │ To                                               │   Distance (mi) │   Duration (hrs) │
# ╞════╪══════════════════════════════════════════════════╪══════════════════════════════════════════════════╪═════════════════╪══════════════════╡
# │  0 │ Big Bend National Park                           │ Golden Gate National Recreation Area             │         1520.18 │            22.72 │
# ├────┼──────────────────────────────────────────────────┼──────────────────────────────────────────────────┼─────────────────┼──────────────────┤
# │  1 │ Golden Gate National Recreation Area             │ Fire Island National Seashore                    │         2978.14 │            43.93 │
# ├────┼──────────────────────────────────────────────────┼──────────────────────────────────────────────────┼─────────────────┼──────────────────┤
# │  2 │ Fire Island National Seashore                    │ Theodore Roosevelt National Park                 │         1827.79 │            27.37 │
# ├────┼──────────────────────────────────────────────────┼──────────────────────────────────────────────────┼─────────────────┼──────────────────┤
# │  3 │ Theodore Roosevelt National Park                 │ Everglades National Park                         │         2391.76 │            34.32 │
# ├────┼──────────────────────────────────────────────────┼──────────────────────────────────────────────────┼─────────────────┼──────────────────┤
# │  4 │ Everglades National Park                         │ Zion National Park                               │         2499.07 │            37.27 │
# ├────┼──────────────────────────────────────────────────┼──────────────────────────────────────────────────┼─────────────────┼──────────────────┤
# │  5 │ Zion National Park                               │ Charles Young Buffalo Soldiers National Monument │         1856.34 │            27.07 │
# ├────┼──────────────────────────────────────────────────┼──────────────────────────────────────────────────┼─────────────────┼──────────────────┤
# │  6 │ Charles Young Buffalo Soldiers National Monument │ Mount Rushmore National Memorial                 │         1249.20 │            18.09 │
# ├────┼──────────────────────────────────────────────────┼──────────────────────────────────────────────────┼─────────────────┼──────────────────┤
# │  7 │ Mount Rushmore National Memorial                 │ Fort Union National Monument                     │          680.70 │            10.33 │
# ├────┼──────────────────────────────────────────────────┼──────────────────────────────────────────────────┼─────────────────┼──────────────────┤
# │  8 │ Totals                                           │                                                  │        15003.18 │           221.10 │
# ╘════╧══════════════════════════════════════════════════╧══════════════════════════════════════════════════╧═════════════════╧══════════════════╛
#
# Route Summary
# ╒════╤══════════════════════════════════════════════════╤══════════════════════════════════════════════════╤═════════════════╤══════════════════╕
# │    │ From                                             │ To                                               │   Distance (mi) │   Duration (hrs) │
# ╞════╪══════════════════════════════════════════════════╪══════════════════════════════════════════════════╪═════════════════╪══════════════════╡
# │  0 │ Big Bend National Park                           │ Fort Union National Monument                     │          547.37 │             8.92 │
# ├────┼──────────────────────────────────────────────────┼──────────────────────────────────────────────────┼─────────────────┼──────────────────┤
# │  1 │ Fort Union National Monument                     │ Zion National Park                               │          639.20 │            10.33 │
# ├────┼──────────────────────────────────────────────────┼──────────────────────────────────────────────────┼─────────────────┼──────────────────┤
# │  2 │ Zion National Park                               │ Golden Gate National Recreation Area             │          756.31 │            11.82 │
# ├────┼──────────────────────────────────────────────────┼──────────────────────────────────────────────────┼─────────────────┼──────────────────┤
# │  3 │ Golden Gate National Recreation Area             │ Mount Rushmore National Memorial                 │         1370.88 │            20.48 │
# ├────┼──────────────────────────────────────────────────┼──────────────────────────────────────────────────┼─────────────────┼──────────────────┤
# │  4 │ Mount Rushmore National Memorial                 │ Theodore Roosevelt National Park                 │          273.72 │             4.62 │
# ├────┼──────────────────────────────────────────────────┼──────────────────────────────────────────────────┼─────────────────┼──────────────────┤
# │  5 │ Theodore Roosevelt National Park                 │ Charles Young Buffalo Soldiers National Monument │         1296.28 │            18.90 │
# ├────┼──────────────────────────────────────────────────┼──────────────────────────────────────────────────┼─────────────────┼──────────────────┤
# │  6 │ Charles Young Buffalo Soldiers National Monument │ Fire Island National Seashore                    │          671.43 │            10.44 │
# ├────┼──────────────────────────────────────────────────┼──────────────────────────────────────────────────┼─────────────────┼──────────────────┤
# │  7 │ Fire Island National Seashore                    │ Everglades National Park                         │         1377.04 │            20.40 │
# ├────┼──────────────────────────────────────────────────┼──────────────────────────────────────────────────┼─────────────────┼──────────────────┤
# │  8 │ Totals                                           │                                                  │         6932.23 │           105.91 │
# ╘════╧══════════════════════════════════════════════════╧══════════════════════════════════════════════════╧═════════════════╧══════════════════╛

# %% [markdown]
# ### 5.3. Comparison of Random Route to Greedy Nearest Neighbor Algorithm
#
# Based on the tables above, it is clear that the random route has a much higher total travel distance and time.

# %%
# Comparing the 2 routes
random_total_miles = route_table_random.iloc[-1]['Distance (mi)']
random_total_hours = route_table_random.iloc[-1]['Duration (hrs)']

gnn_total_miles = route_table_gnn.iloc[-1]['Distance (mi)']
gnn_total_hours = route_table_gnn.iloc[-1]['Duration (hrs)']

# Print summaries
print(f'The random route traverses a total of {random_total_miles:.2f} miles over {random_total_hours:.2f} hours.')
print(f'The GNN route traverses a total of {gnn_total_miles:.2f} miles over {gnn_total_hours:.2f} hours.')

# Percent savings
mile_savings = (random_total_miles - gnn_total_miles) / random_total_miles * 100
hour_savings = (random_total_hours - gnn_total_hours) / random_total_hours * 100

print(f'The GNN route traverses {mile_savings:.2f}% fewer miles in {hour_savings:.2f}% fewer hours.')
# Out:
# The random route traverses a total of 15003.18 miles over 221.10 hours.
# The GNN route traverses a total of 6932.23 miles over 105.91 hours.
# The GNN route traverses 53.79% fewer miles in 52.10% fewer hours.

# %% [markdown]
# ### 5.4. Visualizations of Route Data
#
# Next are some plots of route data
# - Bar charts (distance/duration)
# - Cumulative distance/duration plots

# %%
# Bar plot of travel distances, travel times

# Create leg labels: "From → To" and handle Totals separately
# For random route
route_table_random['Leg'] = route_table_random.apply(
    lambda row: "Totals" if row['From'] == 'Totals' or row['To'] == 'Totals'
    else f"{row['From']} → {row['To']}",
    axis=1
)

# For GNN route
route_table_gnn['Leg'] = route_table_gnn.apply(
    lambda row: "Totals" if row['From'] == 'Totals' or row['To'] == 'Totals'
    else f"{row['From']} → {row['To']}",
    axis=1
)

# Travel distances
plt.figure(figsize=(10, 6))
plt.barh(route_table_random['Leg'], route_table_random['Distance (mi)'], label='Random Route', color='red', alpha=0.7)
plt.barh(route_table_gnn['Leg'], route_table_gnn['Distance (mi)'], label='GNN Route', color='blue', alpha=0.7)
plt.xscale('log')
plt.xlabel('Distance (miles)')
plt.title('Travel Distances Between Route Legs')
plt.legend()
plt.tight_layout()
plt.show()

# Travel times
plt.figure(figsize=(10, 6))
plt.barh(route_table_random['Leg'], route_table_random['Duration (hrs)'], label='Random Route', color='red', alpha=0.7)
plt.barh(route_table_gnn['Leg'], route_table_gnn['Duration (hrs)'], label='GNN Route', color='blue', alpha=0.7)
plt.xscale('linear')
plt.xlabel('Duration (hours)')
plt.title('Travel Durations Between Route Legs')
plt.legend()
plt.tight_layout()
plt.show()

# Cumulative distance plot
# Compute cumulative distances
route_table_random['Cumulative Distance'] = route_table_random['Distance (mi)'].cumsum()
route_table_gnn['Cumulative Distance'] = route_table_gnn['Distance (mi)'].cumsum()

# Plot
plt.figure(figsize=(10, 6))
plt.plot(route_table_random.index + 1, route_table_random['Cumulative Distance'], label='Random Route', color='red', marker='o')
plt.plot(route_table_gnn.index + 1, route_table_gnn['Cumulative Distance'], label='GNN Route', color='blue', marker='o')
plt.xlabel("Leg Number")
plt.ylabel("Cumulative Distance (miles)")
plt.title("Cumulative Travel Distance by Route")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Cumulative duration plot
# Compute cumulative durations
route_table_random['Cumulative Duration'] = route_table_random['Duration (hrs)'].cumsum()
route_table_gnn['Cumulative Duration'] = route_table_gnn['Duration (hrs)'].cumsum()

# Plot
plt.figure(figsize=(10, 6))
plt.plot(route_table_random.index + 1, route_table_random['Cumulative Duration'], label='Random Route', color='red', marker='o')
plt.plot(route_table_gnn.index + 1, route_table_gnn['Cumulative Duration'], label='GNN Route', color='blue', marker='o')
plt.xlabel("Leg Number")
plt.ylabel("Cumulative Duration (hours)")
plt.title("Cumulative Travel Time by Route")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# As shown by the plots above, the GNN route is substantially more efficient than the random route.
#
# ## 6. Final Report
#
# ### 6.1. Introduction to the Dataset
#
# The primary dataset used in this project contains detailed information about national parks across the United States, including their names, coordinates, states, descriptions, and associated amenities and activities. This data was sourced from a publicly available national park data (National Park Service, https://www.nps.gov) using their API, and then it was converted to the structured CSV file.
#
# The secondary dataset used was a basic CSV of state names, abbreviations, and the coordinates of their center points (https://www.kaggle.com/datasets/tennerimaheshwar/us-state-and-territory-latitude-and-longitude-data).
#
# To begin the analysis, exploratory data analysis (EDA) was performed to understand the structure of the dataset, check for missing values, and assess data quality issues like duplicates or improperly formatted strings. Minor preprocessing steps were necessary, such as checking for and trimming whitespace in textual columns and inspecting null values and duplicate rows. This ensured the data was clean and reliable for downstream analysis.
#
# Next, a subset of 9 parks were selected with a relatively spread distribution throughout the country. This was then used for route modeling.
#
# This report is structured to walk you through the dataset characteristics, the algorithms and methodologies implemented for planning a national parks road trip, visualizations created to support route selection, and key conclusions from the project. The sections below elaborate on how the project was implemented, results interpreted, and insights drawn.
#
# ### 6.2. Algorithm
#
# The core task in this project was to create an efficient route to visit a selected subset of national parks spread across the United States. To accomplish this, a Greedy Nearest Neighbors algorithm (GNN) was implemented. This algorithm starts from a home park and iteratively selects the next closest unvisited park, aiming to minimize total distance. More specifically, GNN performs the following steps:
#
# 1. Start at an initial point.
# 2. Mark the starting point as visited.
# 3. From the current point, find the closest unvisited point (i.e., the one with the shortest distance).
# 4. Travel to that point, and mark it as visited.
# 5. Repeat steps 3–4 until all points have been visited.
#
# Further, instead of simply using the Haversine (linear distance including curvature of Earth) distance between each park, we decided to create a more realistic model by incorporating Google Maps (https://www.google.com/maps) travel distance using their API.
#
# Additionally, we incorporated a way to specify the starting location of the trip based on the user's home state, dramatically improving user-friendliness.
#
# Libraries used include:
#
# - `pandas` and `numpy` for data manipulation,
# - `googlemaps` for fetching distance matrices,
# - `folium` for interactive map visualizations,
# - `matplotlib` for plotting, and
# - `math` and `random` for core algorithmic operations.
#
# Multiple approaches were considered such as brute-force but were deemed infeasible due to computational costs and time. The Greedy algorithm, while suboptimal in terms of global optimization, provided a simple and scalable solution with acceptable performance for 9 park routes.
#
# The final implementation precomputes park-to-park distances using the Google Maps API and uses a loop-based nearest selection mechanism to generate the route. The simplicity and transparency of this method made it ideal for educational and visualization purposes.
#
# ### 6.3. Visualizations
#
# 1. National Parks Map
#    Using Folium, we created an initial visualization of all of the National Parks in the US. It was from this map that we determined that outlying parks (AK, HI, etc.) should be removed from the dataset. In addition, it provided a good introduction to creating map visualizations using the Folium library.
#
# 2. Route Maps
#    These visualizations use Folium to display the selected parks on a map along with the route connecting them. It provides a geographical context, allowing users to visually assess the spread of parks across the United States. The map also highlights the starting and ending points, giving clarity to the flow of travel.
#    - Website version: Includes home state starting point and rich tooltips.
#    - Notebook version: Compares random and GNN-generated routes.
#
# 3. Distance Bar Charts
#    Bar charts were created to show travel distances and durations between consecutive parks in the generated route. This helps identify any significantly long jumps that might suggest suboptimal segments or the need for regional re-grouping. It also allows for better planning and potential overnight stays.
#
# 4. Cumulative Line Plots
#    Cumulative line plots were created to show accumulated travel distances and durations over each leg of the generated route. This is an easy to understand visual representation of the data that we originally intended to include as part of the route mapping tool on the website. It is especially useful if the user does not want to visit all parks on the route due to time constraints.
#
# ### 6.4. Final Conclusion
#
# This project successfully created an optimized national park road trip route using a simple yet effective algorithm (GNN). The routes generated were markedly more efficient than one of random chance. The visualizations offered valuable insights into the spatial distribution and travel feasibility of the chosen parks. The website provides a customizable, easy to read route rendered on a map for the user's convenience.
#
# The GNN route is not perfect: we noticed some suboptimal backtracking and questionable choices for the next destination. As such, future work could include improving the route with more advanced optimization algorithms (such as 3-opt Local Optimization or Simulated Annealing), implementing new techniques like the Traveling Salesman Problem (TSP) solver, integrating real-time traffic data from Google Maps, or enhancing the web interface for greater user interaction and customization. Additionally, incorporating park popularity, seasonal weather, or user preferences (such as activities, amenities, or regions of the US) could further enhance the utility of the route planning tool.
